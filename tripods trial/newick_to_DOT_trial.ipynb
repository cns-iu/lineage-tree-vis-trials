# %%
import sys
import string
import random


# consistent labeling
random.seed(1)


class Node(object):
    def __init__(self, length=None, name=None):
        self.name = name
        self._length = length
        # generating a unique id for this node
        self.id = self._gen_random_node_id()
        self.descendants = []
        self.ancestor = None
        self.dot = self._to_dot
        self.leaf_count = self._leaf_count
        self.arch_props = {"label": self.length} if self.length else {}
        self.label = self._to_dot_label

    @classmethod
    def create(cls, name=None, length=None, descendants=None):
        node = cls(name=name, length=length)
        for descendant in descendants or []:
            node.add_descendant(descendant)
        return node

    @property
    def length(self):
        return float(self._length or 0.0)

    @length.setter
    def length(self, len):
        if len is None:
            self._length = len
        else:
            self._length = '%s' % len

    def add_descendant(self, node):
        node.ancestor = self
        self.descendants.append(node)

    def _leaf_count(self):
        sum = 0
        if self.is_leaf:
            self.leaf_count = sum
        for n in self.descendants:
            sum += n.leaf_count()
        return sum

    @property
    def is_leaf(self):
        return not bool(self.descendants)

    def _to_dot_label(self, d={}):
        if d is None:
            d = self.arch_props
        if not len(d):
            return ''

        out = '['
        for i, (key, value) in enumerate(d.items()):
            if isinstance(value, (int, float, complex)):
                out += '%s=%s' % (key, str(value))
            else:
                out += '%s="%s"' % (key, str(value))
            if i < len(d) - 1:  # last
                out += ','
        out += ']'
        return out

    def _gen_random_node_id(self):
        return ''.join(random.choices(string.digits + 'abcdef', k=6))

    def _graph_node(self, nodeFromId, nodeToId=None, props={}):
        if nodeToId:
            return '\n\t"%s" -- "%s" %s;' % (nodeFromId, nodeToId, self._to_dot_label(props))
        else:  # printing out single node
            return '\n\t"%s" %s;' % (nodeFromId, self._to_dot_label(props))

    def _to_dot(self, emptyLabels=False):
        out = ''
        if not self.ancestor:  # first graph node
            out += 'graph {\n\trankdir=LR;\n\tsplines=line;\n\tnode [shape=none]'
            phantom_node_id = self._gen_random_node_id()
            # create a phantom node to attach my first node to
            out += self._graph_node(phantom_node_id, props={"shape": "point"})

        if not self.is_leaf and not self.ancestor:  # father of many, need the label if present
            props = {"shape": "point"}
            if self.name:  # we give the headlabel to the arch
                props["headlabel"] = self.name
            out += self._graph_node(self.id, props={"shape": "point"})
            out += self._graph_node(phantom_node_id, self.id, props=props)

        for n in self.descendants:
            if n.is_leaf:
                if n.name:
                    props = {"label": n.name}
                else:
                    if not emptyLabels:
                        props = {"label": n.id}
                    else:
                        props = {"label": ""}
                out += self._graph_node(n.id, props=props or {})
                out += self._graph_node(self.id, n.id)
            else:  # it has descendants
                out += self._graph_node(n.id, props={"shape": "point"})
                props = {}
                if n.name:  # we give the headlabel to the arch
                    props["headlabel"] = n.name
                out += self._graph_node(self.id, n.id, props=props)
            out += n.dot(emptyLabels=emptyLabels)

        if not self.ancestor:  # first
            out += '\n}\n'
        return out

    def __repr__(self):
        return '[id=%s;name=%s;length=%s;descendants=%s]' % (
            self.id, (self.name or ""), (self._length or ""), str(len(self.descendants) or ""))


def loads(s):
    # Theoretically, you will never parse more than two root nodes.
    return [parse_node(ss.strip()) for ss in s.split(';') if ss.strip()]


def _parse_name_and_length(s):
    l = None
    if ':' in s:
        s, l = s.split(':', 1)
    return s or None, l or None


def _parse_siblings(s):
    bracket_level = 0
    current = []

    for c in (s + ","):
        """
        we loop through every character
        when we stumble upon a comma
        then we should have a node.
        """
        if c == "," and bracket_level == 0:
            # putting the current parsed node into the generator
            yield parse_node("".join(current))
            # resetting character for node name
            current = []
        else:
            # If not, we have a higher level
            if c == "(":
                bracket_level += 1  # up one level
            elif c == ")":
                bracket_level -= 1  # down one level
            current.append(c)


def parse_node(s):
    s = s.strip()
    parts = s.split(')')  # the left part contains the data of my node
    if len(parts) == 1:  # if I don't have a closing parenthesis, I have finished and have no other child nodes
        descendants, label = [], s
    else:
        if not parts[0].startswith('('):  # formatting error: "A),B"
            raise ValueError('Parentheses do not match')
        # analyze the right part
        descendants = list(_parse_siblings(')'.join(parts[:-1])[1:]))
        label = parts[-1]
    name, length = _parse_name_and_length(label)
    return Node.create(name=name, length=length, descendants=descendants)


def convert_newick_to_dot(inputtext, empty_labels=False):
    tree = loads(inputtext)
    output = tree[0].dot(emptyLabels=empty_labels)
    return output


if __name__ == "__main__":
    inputtext = "((((((((((ABALAAAALAL:142,ABALAAAALAR:142)ABALAAAALA:142,(ABALAAAALPA:127,ABALAAAALPP:127)ABALAAAALP:142)ABALAAAAL:100,((ABALAAAARLA:114,ABALAAAARLP:114)ABALAAAARL:142,(ABALAAAARRA:114,ABALAAAARRP:114)ABALAAAARR:142)ABALAAAAR:100)ABALAAAA:53,(((ABALAAAPALL:114,ABALAAAPALR:114)ABALAAAPAL:104,(ABALAAAPARL:133,ABALAAAPARR:133)ABALAAAPAR:104)ABALAAAPA:91,((ABALAAAPPLL:133,ABALAAAPPLR:133)ABALAAAPPL:104,(ABALAAAPPRL:114,ABALAAAPPRR:114)ABALAAAPPR:104)ABALAAAPP:91)ABALAAAP:53)ABALAAA:49,((((ABALAAPAAAL:161,ABALAAPAAAR:161)ABALAAPAAA:123,(ABALAAPAAPA:146,ABALAAPAAPP:146)ABALAAPAAP:123)ABALAAPAA:98,(ABALAAPAPA:123,(ABALAAPAPPA:104,ABALAAPAPPP:104)ABALAAPAPP:123)ABALAAPAP:98)ABALAAPA:55,((ABALAAPPAA:133,(ABALAAPPAPA:104,ABALAAPPAPP:104)ABALAAPPAP:133)ABALAAPPA:89,((ABALAAPPPAA:171,ABALAAPPPAP:171)ABALAAPPPA:95,((ABALAAPPPPAA:228,ABALAAPPPPAP:228)ABALAAPPPPA:133,ABALAAPPPPP:133)ABALAAPPPP:95)ABALAAPPP:89)ABALAAPP:55)ABALAAP:49)ABALAA:34,(((((ABALAPAAAAA:228,ABALAPAAAAP:228)ABALAPAAAA:85,(ABALAPAAAPA:142,ABALAPAAAPP:142)ABALAPAAAP:85)ABALAPAAA:95,((ABALAPAAPAA:193,ABALAPAAPAP:193)ABALAPAAPA:85,((ABALAPAAPPAA:212,ABALAPAAPPAP:212)ABALAPAAPPA:133,ABALAPAAPPP:133)ABALAPAAPP:85)ABALAPAAP:95)ABALAPAA:53,((ABALA
MSPPPPPA:123,MSPPPPPP:123)MSPPPPP:76)MSPPPP:62)MSPPP:70)MSPP:51)MSP:36)MS:39)EMS:34,((((((CAAAAA:104,CAAAAP:104)CAAAA:60,(CAAAPA:108,CAAAPP:108)CAAAP:60)CAAA:68,((CAAPAA:285,CAAPAP:285)CAAPA:89,(CAAPPD:104,CAAPPV:104)CAAPP:89)CAAP:68)CAA:51,((((CAPAAAA:136,CAPAAAP:136)CAPAAA:123,(CAPAAPA:152,CAPAAPP:152)CAPAAP:123)CAPAA:98,((CAPAPAA:142,CAPAPAP:142)CAPAPA:123,(CAPAPPA:152,CAPAPPP:152)CAPAPP:123)CAPAP:98)CAPA:68,(((CAPPAAA:133,CAPPAAP:133)CAPPAA:104,(CAPPAPA:155,CAPPAPP:155)CAPPAP:104)CAPPA:98,((CAPPPAA:155,CAPPPAP:155)CAPPPA:104,(CAPPPPD:171,CAPPPPV:171)CAPPPP:104)CAPPP:98)CAPP:68)CAP:51)CA:53,((((CPAAAA:98,CPAAAP:98)CPAAA:70,(CPAAPA:95,CPAAPP:95)CPAAP:70)CPAA:68,((CPAPAA:104,CPAPAP:104)CPAPA:79,(CPAPPD:114,CPAPPV:114)CPAPP:79)CPAP:68)CPA:51,((((CPPAAAA:136,CPPAAAP:136)CPPAAA:123,(CPPAAPA:152,CPPAAPP:152)CPPAAP:123)CPPAA:98,((CPPAPAA:142,CPPAPAP:142)CPPAPA:123,(CPPAPPA:152,CPPAPPP:152)CPPAPP:123)CPPAP:98)CPPA:68,(((CPPPAAA:133,CPPPAAP:133)CPPPAA:104,(CPPPAPA:155,CPPPAPP:155)CPPPAP:104)CPPPA:98,((CPPPPAA:155,CPPPPAP:155)CPPPPA:104,(CPPPPPD:171,CPPPPPV:171)CPPPPP:104)CPPPP:98)CPPP:68)CPP:51)CP:53)C:45,(((((DAAAA:123,DAAAP:123)DAAA:85,(DAAPA:129,DAAPP:129)DAAP:85)DAA:95,((DAPAA:133,DAPAP:133)DAPA:66,((DAPPAA:142,DAPPAP:142)DAPPA:123,(DAPPPA:180,DAPPPP:180)DAPPP:123)DAPP:66)DAP:95)DA:89,(((DPAAA:123,DPAAP:123)DPAA:85,(DPAPA:127,DPAPP:127)DPAP:85)DPA:95,((DPPAA:133,DPPAP:133)DPPA:66,((DPPPAA:142,DPPPAP:142)DPPPA:123,(DPPPPA:180,DPPPPP:180)DPPPP:123)DPPP:66)DPP:95)DP:89)D:49,(P4A:136,P4P:136)P4:49)P3:45)P2:34)P1:28)zygote:0;"
    output = convert_newick_to_dot(inputtext, empty_labels=True)
    print(output)
# Out:
# graph {
# 	rankdir=LR;
# 	splines=line;
# 	node [shape=none]
# 	"d96abc" [shape="point"];
# 	"3b9e96" [shape="point"];
# 	"d96abc" -- "3b9e96" [shape="point",headlabel="zygote"];
# 	"9981a3" [shape="point"];
# 	"3b9e96" -- "9981a3" [headlabel="P0A"];
# 	"ac1f7c" [shape="point"];
# 	"9981a3" -- "ac1f7c" [headlabel="ABA"];
# 	"b4059c" [shape="point"];
# 	"ac1f7c" -- "b4059c" [headlabel="ABAL"];
# 	"455b88" [shape="point"];
# 	"b4059c" -- "455b88" [headlabel="ABALA"];
# 	"ba41fc" [shape="point"];
# 	"455b88" -- "ba41fc" [headlabel="ABALAA"];
# 	"e0df92" [shape="point"];
# 	"ba41fc" -- "e0df92" [headlabel="ABALAAA"];
# 	"8f9748" [shape="point"];
# 	"e0df92" -- "8f9748" [headlabel="ABALAAAA"];
# 	"d8a2fd" [shape="point"];
# 	"8f9748" -- "d8a2fd" [headlabel="ABALAAAAL"];
# 	"c07b3f" [shape="point"];
# 	"d8a2fd" -- "c07b3f" [headlabel="ABALAAAALA"];
# 	"2dc477" [label="ABALAAAALAL"];
# 	"c07b3f" -- "2dc477" ;
# 	"ac10d6" [label="ABALAAAALAR"];
# 	"c07b3f" -- "ac10d6" ;
# 	"333740" [shape="point"];
# 	"d8a2fd" -- "333740" [headlabel="ABALAAAALP"];
# 	"e008f6" [label="ABALAAAALPA"];
# 	"333740" -- "e008f6" ;
# 	"360377" [label="ABALAAAALPP"];
# 	"333740" -- "360377" ;
# 	"8fc8d3" [shape="point"];
# 	"8f9748" -- "8fc8d3" [headlabel="ABALAAAAR"];
# 	"8903c6" [shape="point"];
# 	"8fc8d3" -- "8903c6" [headlabel="ABALAAAARL"];
# 	"15bbe6" [label="ABALAAAARLA"];
# 	"8903c6" -- "15bbe6" ;
# 	"da49ed" [label="ABALAAAARLP"];
# 	"8903c6" -- "da49ed" ;
# 	"0bf962" [shape="point"];
# 	"8fc8d3" -- "0bf962" [headlabel="ABALAAAARR"];
# 	"28ba57" [label="ABALAAAARRA"];
# 	"0bf962" -- "28ba57" ;
# 	"8c8670" [label="ABALAAAARRP"];
# 	"0bf962" -- "8c8670" ;
# 	"4fb640" [shape="point"];
# 	"e0df92" -- "4fb640" [headlabel="ABALAAAP"];
# 	"c31951" [shape="point"];
# 	"4fb640" -- "c31951" [headlabel="ABALAAAPA"];
# 	"938755" [shape="point"];
# 	"c31951" -- "938755" [headlabel="ABALAAAPAL"];
# 	"f0cdeb" [label="ABALAAAPALL"];
# 	"938755" -- "f0cdeb" ;
# 	"c8860d" [label="ABALAAAPALR"];
# 	"938755" -- "c8860d" ;
# 	"4da100" [shape="point"];
# 	"c31951" -- "4da100" [headlabel="ABALAAAPAR"];
# 	"899703" [label="ABALAAAPARL"];
# 	"4da100" -- "899703" ;
# 	"29dccd" [label="ABALAAAPARR"];
# 	"4da100" -- "29dccd" ;
# 	"04fe4d" [shape="point"];
# 	"4fb640" -- "04fe4d" [headlabel="ABALAAAPP"];
# 	"1e839d" [shape="point"];
# 	"04fe4d" -- "1e839d" [headlabel="ABALAAAPPL"];
# 	"2824b7" [label="ABALAAAPPLL"];
# 	"1e839d" -- "2824b7" ;
# 	"570663" [label="ABALAAAPPLR"];
# 	"1e839d" -- "570663" ;
# 	"3a695a" [shape="point"];
# 	"04fe4d" -- "3a695a" [headlabel="ABALAAAPPR"];
# 	"002b2b" [label="ABALAAAPPRL"];
# 	"3a695a" -- "002b2b" ;
# 	"a83fc8" [label="ABALAAAPPRR"];
# 	"3a695a" -- "a83fc8" ;
# 	"dbb262" [shape="point"];
# 	"ba41fc" -- "dbb262" [headlabel="ABALAAP"];
# 	"a11e03" [shape="point"];
# 	"dbb262" -- "a11e03" [headlabel="ABALAAPA"];
# 	"e3c9d5" [shape="point"];
# 	"a11e03" -- "e3c9d5" [headlabel="ABALAAPAA"];
# 	"475de0" [shape="point"];
# 	"e3c9d5" -- "475de0" [headlabel="ABALAAPAAA"];
# 	"dfb865" [label="ABALAAPAAAL"];
# 	"475de0" -- "dfb865" ;
# 	"3a631a" [label="ABALAAPAAAR"];
# 	"475de0" -- "3a631a" ;
# 	"7f3b12" [shape="point"];
# 	"e3c9d5" -- "7f3b12" [headlabel="ABALAAPAAP"];
# 	"35fc53" [label="ABALAAPAAPA"];
# 	"7f3b12" -- "35fc53" ;
# 	"ade5ea" [label="ABALAAPAAPP"];
# 	"7f3b12" -- "ade5ea" ;
# 	"e74cd0" [shape="point"];
# 	"a11e03" -- "e74cd0" [headlabel="ABALAAPAP"];
# 	"54d9fe" [label="ABALAAPAPA"];
# 	"e74cd0" -- "54d9fe" ;
# 	"9314e9" [shape="point"];
# 	"e74cd0" -- "9314e9" [headlabel="ABALAAPAPP"];
# 	"28101d" [label="ABALAAPAPPA"];
# 	"9314e9" -- "28101d" ;
# 	"cd59c6" [label="ABALAAPAPPP"];
# 	"9314e9" -- "cd59c6" ;
# 	"e05ece" [shape="point"];
# 	"dbb262" -- "e05ece" [headlabel="ABALAAPP"];
# 	"eff139" [shape="point"];
# 	"e05ece" -- "eff139" [headlabel="ABALAAPPA"];
# 	"f6123b" [label="ABALAAPPAA"];
# 	"eff139" -- "f6123b" ;
# 	"f49751" [shape="point"];
# 	"eff139" -- "f49751" [headlabel="ABALAAPPAP"];
# 	"1e6fe4" [label="ABALAAPPAPA"];
# 	"f49751" -- "1e6fe4" ;
# 	"471a00" [label="ABALAAPPAPP"];
# 	"f49751" -- "471a00" ;
# 	"18e4e2" [shape="point"];
# 	"e05ece" -- "18e4e2" [headlabel="ABALAAPPP"];
# 	"aaf645" [shape="point"];
# 	"18e4e2" -- "aaf645" [headlabel="ABALAAPPPA"];
# 	"f8ba48" [label="ABALAAPPPAA"];
# 	"aaf645" -- "f8ba48" ;
# 	"4314f7" [label="ABALAAPPPAP"];
# 	"aaf645" -- "4314f7" ;
# 	"f2cfd5" [shape="point"];
# 	"18e4e2" -- "f2cfd5" [headlabel="ABALAAPPPP"];
# 	"811a4c" [shape="point"];
# 	"f2cfd5" -- "811a4c" [headlabel="ABALAAPPPPA"];
# 	"5de458" [label="ABALAAPPPPAA"];
# 	"811a4c" -- "5de458" ;
# 	"993031" [label="ABALAAPPPPAP"];
# 	"811a4c" -- "993031" ;
# 	"7d28c1" [label="ABALAAPPPPP"];
# 	"f2cfd5" -- "7d28c1" ;
# 	"590da5" [shape="point"];
# 	"455b88" -- "590da5" [headlabel="ABALAP"];
# 	"8fb6b9" [shape="point"];
# 	"590da5" -- "8fb6b9" [headlabel="ABALAPA"];
# 	"3b0370" [shape="point"];
# 	"8fb6b9" -- "3b0370" [headlabel="ABALAPAA"];
# 	"4a018e" [shape="point"];
# 	"3b0370" -- "4a018e" [headlabel="ABALAPAAA"];
# 	"5224d6" [shape="point"];
# 	"4a018e" -- "5224d6" [headlabel="ABALAPAAAA"];
# 	"88d765" [label="ABALAPAAAAA"];
# 	"5224d6" -- "88d765" ;
# 	"40a690" [label="ABALAPAAAAP"];
# 	"5224d6" -- "40a690" ;
# 	"7368ee" [shape="point"];
# 	"4a018e" -- "7368ee" [headlabel="ABALAPAAAP"];
# 	"693088" [label="ABALAPAAAPA"];
# 	"7368ee" -- "693088" ;
# 	"a7ab37" [label="ABALAPAAAPP"];
# 	"7368ee" -- "a7ab37" ;
# 	"f19614" [shape="point"];
# 	"3b0370" -- "f19614" [headlabel="ABALAPAAP"];
# 	"f92439" [shape="point"];
# 	"f19614" -- "f92439" [headlabel="ABALAPAAPA"];
# 	"2ce4bd" [label="ABALAPAAPAA"];
# 	"f92439" -- "2ce4bd" ;
# 	"5bb9de" [label="ABALAPAAPAP"];
# 	"f92439" -- "5bb9de" ;
# 	"c6252e" [shape="point"];
# 	"f19614" -- "c6252e" [headlabel="ABALAPAAPP"];
# 	"4ef2cd" [shape="point"];
# 	"c6252e" -- "4ef2cd" [headlabel="ABALAPAAPPA"];
# 	"c0ab58" [label="ABALAPAAPPAA"];
# 	"4ef2cd" -- "c0ab58" ;
# 	"2b0fca" [label="ABALAPAAPPAP"];
# 	"4ef2cd" -- "2b0fca" ;
# 	"ab7ef6" [label="ABALAPAAPPP"];
# 	"c6252e" -- "ab7ef6" ;
# 	"8b65a0" [shape="point"];
# 	"8fb6b9" -- "8b65a0" [headlabel="ABALAPAP"];
# 	"7746ca" [shape="point"];
# 	"8b65a0" -- "7746ca" [headlabel="ABALAPAPA"];
# 	"a9d348" [label="ABALAPAPAA"];
# 	"7746ca" -- "a9d348" ;
# 	"948580" [shape="point"];
# 	"7746ca" -- "948580" [headlabel="ABALAPAPAP"];
# 	"641c1b" [shape="point"];
# 	"948580" -- "641c1b" [headlabel="ABALAPAPAPA"];
# 	"494acc" [label="ABALAPAPAPAA"];
# 	"641c1b" -- "494acc" ;
# 	"f87dc9" [label="ABALAPAPAPAP"];
# 	"641c1b" -- "f87dc9" ;
# 	"8fcf28" [label="ABALAPAPAPP"];
# 	"948580" -- "8fcf28" ;
# 	"82d770" [shape="point"];
# 	"8b65a0" -- "82d770" [headlabel="ABALAPAPP"];
# 	"6d9beb" [shape="point"];
# 	"82d770" -- "6d9beb" [headlabel="ABALAPAPPA"];
# 	"d6bf42" [shape="point"];
# 	"6d9beb" -- "d6bf42" [headlabel="ABALAPAPPAA"];
# 	"7a6304" [label="ABALAPAPPAAA"];
# 	"d6bf42" -- "7a6304" ;
# 	"9ed8f7" [label="ABALAPAPPAAP"];
# 	"d6bf42" -- "9ed8f7" ;
# 	"985066" [label="ABALAPAPPAP"];
# 	"6d9beb" -- "985066" ;
# 	"d954bd" [shape="point"];
# 	"82d770" -- "d954bd" [headlabel="ABALAPAPPP"];
# 	"7baaa6" [label="ABALAPAPPPA"];
# 	"d954bd" -- "7baaa6" ;
# 	"aaecdc" [label="ABALAPAPPPP"];
# 	"d954bd" -- "aaecdc" ;
# 	"d42581" [shape="point"];
# 	"590da5" -- "d42581" [headlabel="ABALAPP"];
# 	"7623d7" [shape="point"];
# 	"d42581" -- "7623d7" [headlabel="ABALAPPA"];
# 	"bd0e95" [shape="point"];
# 	"7623d7" -- "bd0e95" [headlabel="ABALAPPAA"];
# 	"33e41d" [label="ABALAPPAAA"];
# 	"bd0e95" -- "33e41d" ;
# 	"2cd53f" [shape="point"];
# 	"bd0e95" -- "2cd53f" [headlabel="ABALAPPAAP"];
# 	"858b2a" [label="ABALAPPAAPA"];
# 	"2cd53f" -- "858b2a" ;
# 	"bd4938" [label="ABALAPPAAPP"];
# 	"2cd53f" -- "bd4938" ;
# 	"5d1b16" [shape="point"];
# 	"7623d7" -- "5d1b16" [headlabel="ABALAPPAP"];
# 	"822b5c" [shape="point"];
# 	"5d1b16" -- "822b5c" [headlabel="ABALAPPAPA"];
# 	"6cc3a2" [label="ABALAPPAPAA"];
# 	"822b5c" -- "6cc3a2" ;
# 	"f7eb94" [label="ABALAPPAPAP"];
# 	"822b5c" -- "f7eb94" ;
# 	"30bdf9" [shape="point"];
# 	"5d1b16" -- "30bdf9" [headlabel="ABALAPPAPP"];
# 	"3bb416" [label="ABALAPPAPPA"];
# 	"30bdf9" -- "3bb416" ;
# 	"71209e" [label="ABALAPPAPPP"];
# 	"30bdf9" -- "71209e" ;
# 	"fbdb8e" [shape="point"];
# 	"d42581" -- "fbdb8e" [headlabel="ABALAPPP"];
# 	"959880" [shape="point"];
# 	"fbdb8e" -- "959880" [headlabel="ABALAPPPA"];
# 	"9e6ec2" [shape="point"];
# 	"959880" -- "9e6ec2" [headlabel="ABALAPPPAA"];
# 	"93b59e" [label="ABALAPPPAAA"];
# 	"9e6ec2" -- "93b59e" ;
# 	"f0cd56" [label="ABALAPPPAAP"];
# 	"9e6ec2" -- "f0cd56" ;
# 	"afa30e" [shape="point"];
# 	"959880" -- "afa30e" [headlabel="ABALAPPPAP"];
# 	"d04110" [shape="point"];
# 	"afa30e" -- "d04110" [headlabel="ABALAPPPAPA"];
# 	"e02a06" [label="ABALAPPPAPAA"];
# 	"d04110" -- "e02a06" ;
# 	"27de00" [label="ABALAPPPAPAP"];
# 	"d04110" -- "27de00" ;
# 	"abada6" [label="ABALAPPPAPP"];
# 	"afa30e" -- "abada6" ;
# 	"cf91a7" [shape="point"];
# 	"fbdb8e" -- "cf91a7" [headlabel="ABALAPPPP"];
# 	"726be0" [shape="point"];
# 	"cf91a7" -- "726be0" [headlabel="ABALAPPPPA"];
# 	"2edd01" [shape="point"];
# 	"726be0" -- "2edd01" [headlabel="ABALAPPPPAA"];
# 	"563e6a" [label="ABALAPPPPAAA"];
# 	"2edd01" -- "563e6a" ;
# 	"bbbc4f" [label="ABALAPPPPAAP"];
# 	"2edd01" -- "bbbc4f" ;
# 	"d75f08" [label="ABALAPPPPAP"];
# 	"726be0" -- "d75f08" ;
# 	"463855" [shape="point"];
# 	"cf91a7" -- "463855" [headlabel="ABALAPPPPP"];
# 	"81c106" [label="ABALAPPPPPA"];
# 	"463855" -- "81c106" ;
# 	"b52ccd" [label="ABALAPPPPPP"];
# 	"463855" -- "b52ccd" ;
# 	"6a5c0c" [shape="point"];
# 	"b4059c" -- "6a5c0c" [headlabel="ABALP"];
# 	"64d7ba" [shape="point"];
# 	"6a5c0c" -- "64d7ba" [headlabel="ABALPA"];
# 	"48e1d1" [shape="point"];
# 	"64d7ba" -- "48e1d1" [headlabel="ABALPAA"];
# 	"14ebf8" [shape="point"];
# 	"48e1d1" -- "14ebf8" [headlabel="ABALPAAA"];
# 	"018414" [shape="point"];
# 	"14ebf8" -- "018414" [headlabel="ABALPAAAA"];
# 	"ec289f" [shape="point"];
# 	"018414" -- "ec289f" [headlabel="ABALPAAAAA"];
# 	"2e551f" [label="ABALPAAAAAA"];
# 	"ec289f" -- "2e551f" ;
# 	"7eefde" [label="ABALPAAAAAP"];
# 	"ec289f" -- "7eefde" ;
# 	"a9e26b" [shape="point"];
# 	"018414" -- "a9e26b" [headlabel="ABALPAAAAP"];
# 	"cbb5fa" [label="ABALPAAAAPA"];
# 	"a9e26b" -- "cbb5fa" ;
# 	"67f822" [label="ABALPAAAAPP"];
# 	"a9e26b" -- "67f822" ;
# 	"d734b0" [shape="point"];
# 	"14ebf8" -- "d734b0" [headlabel="ABALPAAAP"];
# 	"4e9de6" [shape="point"];
# 	"d734b0" -- "4e9de6" [headlabel="ABALPAAAPA"];
# 	"a811da" [label="ABALPAAAPAA"];
# 	"4e9de6" -- "a811da" ;
# 	"2d05db" [label="ABALPAAAPAP"];
# 	"4e9de6" -- "2d05db" ;
# 	"76ec90" [shape="point"];
# 	"d734b0" -- "76ec90" [headlabel="ABALPAAAPP"];
# 	"a8fcbd" [label="ABALPAAAPPA"];
# 	"76ec90" -- "a8fcbd" ;
# 	"f43bc8" [label="ABALPAAAPPP"];
# 	"76ec90" -- "f43bc8" ;
# 	"dca16a" [shape="point"];
# 	"48e1d1" -- "dca16a" [headlabel="ABALPAAP"];
# 	"56024d" [shape="point"];
# 	"dca16a" -- "56024d" [headlabel="ABALPAAPA"];
# 	"8f2afb" [shape="point"];
# 	"56024d" -- "8f2afb" [headlabel="ABALPAAPAA"];
# 	"9888df" [label="ABALPAAPAAA"];
# 	"8f2afb" -- "9888df" ;
# 	"6a4489" [label="ABALPAAPAAP"];
# 	"8f2afb" -- "6a4489" ;
# 	"5b7571" [shape="point"];
# 	"56024d" -- "5b7571" [headlabel="ABALPAAPAP"];
# 	"956eea" [label="ABALPAAPAPA"];
# 	"5b7571" -- "956eea" ;
# 	"eed67c" [label="ABALPAAPAPP"];
# 	"5b7571" -- "eed67c" ;
# 	"a1447c" [shape="point"];
# 	"dca16a" -- "a1447c" [headlabel="ABALPAAPP"];
# 	"fb12f3" [shape="point"];
# 	"a1447c" -- "fb12f3" [headlabel="ABALPAAPPA"];
# 	"94f48b" [label="ABALPAAPPAA"];
# 	"fb12f3" -- "94f48b" ;
# 	"b6c7b7" [label="ABALPAAPPAP"];
# 	"fb12f3" -- "b6c7b7" ;
# 	"5ff186" [shape="point"];
# 	"a1447c" -- "5ff186" [headlabel="ABALPAAPPP"];
# 	"047f6b" [label="ABALPAAPPPA"];
# 	"5ff186" -- "047f6b" ;
# 	"d19f88" [label="ABALPAAPPPP"];
# 	"5ff186" -- "d19f88" ;
# 	"5afc06" [shape="point"];
# 	"64d7ba" -- "5afc06" [headlabel="ABALPAP"];
# 	"026ea3" [shape="point"];
# 	"5afc06" -- "026ea3" [headlabel="ABALPAPA"];
# 	"264b43" [shape="point"];
# 	"026ea3" -- "264b43" [headlabel="ABALPAPAA"];
# 	"c570fa" [shape="point"];
# 	"264b43" -- "c570fa" [headlabel="ABALPAPAAA"];
# 	"6e386e" [label="ABALPAPAAAA"];
# 	"c570fa" -- "6e386e" ;
# 	"f47e83" [label="ABALPAPAAAP"];
# 	"c570fa" -- "f47e83" ;
# 	"389f89" [shape="point"];
# 	"264b43" -- "389f89" [headlabel="ABALPAPAAP"];
# 	"ef487c" [label="ABALPAPAAPA"];
# 	"389f89" -- "ef487c" ;
# 	"d34b62" [label="ABALPAPAAPP"];
# 	"389f89" -- "d34b62" ;
# 	"1b1540" [shape="point"];
# 	"026ea3" -- "1b1540" [headlabel="ABALPAPAP"];
# 	"a339e6" [shape="point"];
# 	"1b1540" -- "a339e6" [headlabel="ABALPAPAPA"];
# 	"57592e" [label="ABALPAPAPAA"];
# 	"a339e6" -- "57592e" ;
# 	"2418b9" [shape="point"];
# 	"a339e6" -- "2418b9" [headlabel="ABALPAPAPAP"];
# 	"b805ba" [label="ABALPAPAPAPA"];
# 	"2418b9" -- "b805ba" ;
# 	"ce5752" [label="ABALPAPAPAPP"];
# 	"2418b9" -- "ce5752" ;
# 	"524ca0" [shape="point"];
# 	"1b1540" -- "524ca0" [headlabel="ABALPAPAPP"];
# 	"004913" [label="ABALPAPAPPA"];
# 	"524ca0" -- "004913" ;
# 	"af5980" [label="ABALPAPAPPP"];
# 	"524ca0" -- "af5980" ;
# 	"52ce5e" [shape="point"];
# 	"5afc06" -- "52ce5e" [headlabel="ABALPAPP"];
# 	"dd5e2d" [shape="point"];
# 	"52ce5e" -- "dd5e2d" [headlabel="ABALPAPPA"];
# 	"368448" [shape="point"];
# 	"dd5e2d" -- "368448" [headlabel="ABALPAPPAA"];
# 	"a485f5" [label="ABALPAPPAAA"];
# 	"368448" -- "a485f5" ;
# 	"ea8082" [shape="point"];
# 	"368448" -- "ea8082" [headlabel="ABALPAPPAAP"];
# 	"cad9d6" [label="ABALPAPPAAPA"];
# 	"ea8082" -- "cad9d6" ;
# 	"a98986" [label="ABALPAPPAAPP"];
# 	"ea8082" -- "a98986" ;
# 	"a2e2e3" [shape="point"];
# 	"dd5e2d" -- "a2e2e3" [headlabel="ABALPAPPAP"];
# 	"7615a8" [label="ABALPAPPAPA"];
# 	"a2e2e3" -- "7615a8" ;
# 	"8dba04" [label="ABALPAPPAPP"];
# 	"a2e2e3" -- "8dba04" ;
# 	"cd3c38" [shape="point"];
# 	"52ce5e" -- "cd3c38" [headlabel="ABALPAPPP"];
# 	"68e7c9" [shape="point"];
# 	"cd3c38" -- "68e7c9" [headlabel="ABALPAPPPA"];
# 	"67194a" [label="ABALPAPPPAA"];
# 	"68e7c9" -- "67194a" ;
# 	"c90fea" [label="ABALPAPPPAP"];
# 	"68e7c9" -- "c90fea" ;
# 	"854fea" [shape="point"];
# 	"cd3c38" -- "854fea" [headlabel="ABALPAPPPP"];
# 	"6e6907" [label="ABALPAPPPPA"];
# 	"854fea" -- "6e6907" ;
# 	"0b0012" [label="ABALPAPPPPP"];
# 	"854fea" -- "0b0012" ;
# 	"7beba6" [shape="point"];
# 	"6a5c0c" -- "7beba6" [headlabel="ABALPP"];
# 	"a3381e" [shape="point"];
# 	"7beba6" -- "a3381e" [headlabel="ABALPPA"];
# 	"cef298" [shape="point"];
# 	"a3381e" -- "cef298" [headlabel="ABALPPAA"];
# 	"cb3789" [shape="point"];
# 	"cef298" -- "cb3789" [headlabel="ABALPPAAA"];
# 	"80ae2a" [label="ABALPPAAAA"];
# 	"cb3789" -- "80ae2a" ;
# 	"fac777" [shape="point"];
# 	"cb3789" -- "fac777" [headlabel="ABALPPAAAP"];
# 	"75bf0e" [label="ABALPPAAAPA"];
# 	"fac777" -- "75bf0e" ;
# 	"6d2b15" [label="ABALPPAAAPP"];
# 	"fac777" -- "6d2b15" ;
# 	"cfea53" [shape="point"];
# 	"cef298" -- "cfea53" [headlabel="ABALPPAAP"];
# 	"ed2610" [label="ABALPPAAPA"];
# 	"cfea53" -- "ed2610" ;
# 	"abe860" [shape="point"];
# 	"cfea53" -- "abe860" [headlabel="ABALPPAAPP"];
# 	"12cac4" [label="ABALPPAAPPA"];
# 	"abe860" -- "12cac4" ;
# 	"2fdf06" [label="ABALPPAAPPP"];
# 	"abe860" -- "2fdf06" ;
# 	"5cfa1d" [shape="point"];
# 	"a3381e" -- "5cfa1d" [headlabel="ABALPPAP"];
# 	"529dc9" [shape="point"];
# 	"5cfa1d" -- "529dc9" [headlabel="ABALPPAPA"];
# 	"68a7f3" [shape="point"];
# 	"529dc9" -- "68a7f3" [headlabel="ABALPPAPAA"];
# 	"6cebbb" [label="ABALPPAPAAA"];
# 	"68a7f3" -- "6cebbb" ;
# 	"a83c1a" [label="ABALPPAPAAP"];
# 	"68a7f3" -- "a83c1a" ;
# 	"62663d" [shape="point"];
# 	"529dc9" -- "62663d" [headlabel="ABALPPAPAP"];
# 	"0f4469" [label="ABALPPAPAPA"];
# 	"62663d" -- "0f4469" ;
# 	"fb5878" [label="ABALPPAPAPP"];
# 	"62663d" -- "fb5878" ;
# 	"99c40d" [shape="point"];
# 	"5cfa1d" -- "99c40d" [headlabel="ABALPPAPP"];
# 	"836d98" [shape="point"];
# 	"99c40d" -- "836d98" [headlabel="ABALPPAPPA"];
# 	"b52454" [label="ABALPPAPPAA"];
# 	"836d98" -- "b52454" ;
# 	"72243c" [label="ABALPPAPPAP"];
# 	"836d98" -- "72243c" ;
# 	"1d374c" [shape="point"];
# 	"99c40d" -- "1d374c" [headlabel="ABALPPAPPP"];
# 	"1364af" [shape="point"];
# 	"1d374c" -- "1364af" [headlabel="ABALPPAPPPA"];
# 	"63a1c0" [label="ABALPPAPPPAA"];
# 	"1364af" -- "63a1c0" ;
# 	"b6a928" [label="ABALPPAPPPAP"];
# 	"1364af" -- "b6a928" ;
# 	"5d3b58" [label="ABALPPAPPPP"];
# 	"1d374c" -- "5d3b58" ;
# 	"4907e3" [shape="point"];
# 	"7beba6" -- "4907e3" [headlabel="ABALPPP"];
# 	"97ad78" [shape="point"];
# 	"4907e3" -- "97ad78" [headlabel="ABALPPPA"];
# 	"a067f9" [shape="point"];
# 	"97ad78" -- "a067f9" [headlabel="ABALPPPAA"];
# 	"794aae" [shape="point"];
# 	"a067f9" -- "794aae" [headlabel="ABALPPPAAA"];
# 	"bd6e2b" [label="ABALPPPAAAA"];
# 	"794aae" -- "bd6e2b" ;
# 	"4013c6" [label="ABALPPPAAAP"];
# 	"794aae" -- "4013c6" ;
# 	"3d8ee1" [shape="point"];
# 	"a067f9" -- "3d8ee1" [headlabel="ABALPPPAAP"];
# 	"8dfc64" [label="ABALPPPAAPD"];
# 	"3d8ee1" -- "8dfc64" ;
# 	"1d2870" [label="ABALPPPAAPV"];
# 	"3d8ee1" -- "1d2870" ;
# 	"0e558a" [shape="point"];
# 	"97ad78" -- "0e558a" [headlabel="ABALPPPAP"];
# 	"22e408" [shape="point"];
# 	"0e558a" -- "22e408" [headlabel="ABALPPPAPA"];
# 	"38835e" [label="ABALPPPAPAD"];
# 	"22e408" -- "38835e" ;
# 	"fc1e7d" [label="ABALPPPAPAV"];
# 	"22e408" -- "fc1e7d" ;
# 	"6fc919" [shape="point"];
# 	"0e558a" -- "6fc919" [headlabel="ABALPPPAPP"];
# 	"fd6fcd" [label="ABALPPPAPPA"];
# 	"6fc919" -- "fd6fcd" ;
# 	"9d4dcc" [shape="point"];
# 	"6fc919" -- "9d4dcc" [headlabel="ABALPPPAPPP"];
# 	"a6e7e8" [label="ABALPPPAPPPA"];
# 	"9d4dcc" -- "a6e7e8" ;
# 	"e76952" [label="ABALPPPAPPPP"];
# 	"9d4dcc" -- "e76952" ;
# 	"a89c94" [shape="point"];
# 	"4907e3" -- "a89c94" [headlabel="ABALPPPP"];
# 	"5be09a" [shape="point"];
# 	"a89c94" -- "5be09a" [headlabel="ABALPPPPA"];
# 	"d901ad" [shape="point"];
# 	"5be09a" -- "d901ad" [headlabel="ABALPPPPAA"];
# 	"c0253e" [label="ABALPPPPAAD"];
# 	"d901ad" -- "c0253e" ;
# 	"2158df" [label="ABALPPPPAAV"];
# 	"d901ad" -- "2158df" ;
# 	"d275b0" [shape="point"];
# 	"5be09a" -- "d275b0" [headlabel="ABALPPPPAP"];
# 	"4347b4" [shape="point"];
# 	"d275b0" -- "4347b4" [headlabel="ABALPPPPAPA"];
# 	"4f8991" [label="ABALPPPPAPAA"];
# 	"4347b4" -- "4f8991" ;
# 	"2e414b" [label="ABALPPPPAPAP"];
# 	"4347b4" -- "2e414b" ;
# 	"dfd15e" [label="ABALPPPPAPP"];
# 	"d275b0" -- "dfd15e" ;
# 	"a9d77d" [shape="point"];
# 	"a89c94" -- "a9d77d" [headlabel="ABALPPPPP"];
# 	"5fb3e0" [shape="point"];
# 	"a9d77d" -- "5fb3e0" [headlabel="ABALPPPPPA"];
# 	"d6f312" [label="ABALPPPPPAA"];
# 	"5fb3e0" -- "d6f312" ;
# 	"91430f" [label="ABALPPPPPAP"];
# 	"5fb3e0" -- "91430f" ;
# 	"fd9887" [shape="point"];
# 	"a9d77d" -- "fd9887" [headlabel="ABALPPPPPP"];
# 	"756a32" [shape="point"];
# 	"fd9887" -- "756a32" [headlabel="ABALPPPPPPA"];
# 	"f0480c" [label="ABALPPPPPPAA"];
# 	"756a32" -- "f0480c" ;
# 	"1d0834" [label="ABALPPPPPPAP"];
# 	"756a32" -- "1d0834" ;
# 	"b516bc" [shape="point"];
# 	"fd9887" -- "b516bc" [headlabel="ABALPPPPPPP"];
# 	"a4e670" [label="ABALPPPPPPPA"];
# 	"b516bc" -- "a4e670" ;
# 	"01aaf6" [label="ABALPPPPPPPP"];
# 	"b516bc" -- "01aaf6" ;
# 	"a44401" [shape="point"];
# 	"ac1f7c" -- "a44401" [headlabel="ABAR"];
# 	"2bcfe0" [shape="point"];
# 	"a44401" -- "2bcfe0" [headlabel="ABARA"];
# 	"f76ec2" [shape="point"];
# 	"2bcfe0" -- "f76ec2" [headlabel="ABARAA"];
# 	"2d468e" [shape="point"];
# 	"f76ec2" -- "2d468e" [headlabel="ABARAAA"];
# 	"0bd108" [shape="point"];
# 	"2d468e" -- "0bd108" [headlabel="ABARAAAA"];
# 	"0b47a0" [shape="point"];
# 	"0bd108" -- "0b47a0" [headlabel="ABARAAAAA"];
# 	"b2c895" [shape="point"];
# 	"0b47a0" -- "b2c895" [headlabel="ABARAAAAAA"];
# 	"d311fa" [label="ABARAAAAAAA"];
# 	"b2c895" -- "d311fa" ;
# 	"2bf93f" [label="ABARAAAAAAP"];
# 	"b2c895" -- "2bf93f" ;
# 	"632fbe" [shape="point"];
# 	"0b47a0" -- "632fbe" [headlabel="ABARAAAAAP"];
# 	"4687d1" [label="ABARAAAAAPA"];
# 	"632fbe" -- "4687d1" ;
# 	"3f99a3" [label="ABARAAAAAPP"];
# 	"632fbe" -- "3f99a3" ;
# 	"82ef10" [shape="point"];
# 	"0bd108" -- "82ef10" [headlabel="ABARAAAAP"];
# 	"178dbb" [shape="point"];
# 	"82ef10" -- "178dbb" [headlabel="ABARAAAAPA"];
# 	"58d859" [label="ABARAAAAPAA"];
# 	"178dbb" -- "58d859" ;
# 	"948404" [label="ABARAAAAPAP"];
# 	"178dbb" -- "948404" ;
# 	"f45318" [label="ABARAAAAPP"];
# 	"82ef10" -- "f45318" ;
# 	"a2193a" [shape="point"];
# 	"2d468e" -- "a2193a" [headlabel="ABARAAAP"];
# 	"13b1fc" [shape="point"];
# 	"a2193a" -- "13b1fc" [headlabel="ABARAAAPA"];
# 	"875602" [shape="point"];
# 	"13b1fc" -- "875602" [headlabel="ABARAAAPAA"];
# 	"500334" [label="ABARAAAPAAA"];
# 	"875602" -- "500334" ;
# 	"8433e3" [label="ABARAAAPAAP"];
# 	"875602" -- "8433e3" ;
# 	"4597ca" [shape="point"];
# 	"13b1fc" -- "4597ca" [headlabel="ABARAAAPAP"];
# 	"ac32e1" [label="ABARAAAPAPA"];
# 	"4597ca" -- "ac32e1" ;
# 	"ce2d20" [label="ABARAAAPAPP"];
# 	"4597ca" -- "ce2d20" ;
# 	"29db27" [shape="point"];
# 	"a2193a" -- "29db27" [headlabel="ABARAAAPP"];
# 	"9d663d" [shape="point"];
# 	"29db27" -- "9d663d" [headlabel="ABARAAAPPA"];
# 	"344630" [label="ABARAAAPPAA"];
# 	"9d663d" -- "344630" ;
# 	"4357da" [label="ABARAAAPPAP"];
# 	"9d663d" -- "4357da" ;
# 	"756702" [shape="point"];
# 	"29db27" -- "756702" [headlabel="ABARAAAPPP"];
# 	"ee911c" [label="ABARAAAPPPA"];
# 	"756702" -- "ee911c" ;
# 	"e8eec5" [label="ABARAAAPPPP"];
# 	"756702" -- "e8eec5" ;
# 	"727d03" [shape="point"];
# 	"f76ec2" -- "727d03" [headlabel="ABARAAP"];
# 	"255d44" [shape="point"];
# 	"727d03" -- "255d44" [headlabel="ABARAAPA"];
# 	"5e2348" [shape="point"];
# 	"255d44" -- "5e2348" [headlabel="ABARAAPAA"];
# 	"ddcaa5" [shape="point"];
# 	"5e2348" -- "ddcaa5" [headlabel="ABARAAPAAA"];
# 	"eda128" [label="ABARAAPAAAA"];
# 	"ddcaa5" -- "eda128" ;
# 	"fb35f8" [label="ABARAAPAAAP"];
# 	"ddcaa5" -- "fb35f8" ;
# 	"0fb012" [shape="point"];
# 	"5e2348" -- "0fb012" [headlabel="ABARAAPAAP"];
# 	"1f049f" [label="ABARAAPAAPA"];
# 	"0fb012" -- "1f049f" ;
# 	"33d565" [label="ABARAAPAAPP"];
# 	"0fb012" -- "33d565" ;
# 	"611ad0" [shape="point"];
# 	"255d44" -- "611ad0" [headlabel="ABARAAPAP"];
# 	"a359da" [shape="point"];
# 	"611ad0" -- "a359da" [headlabel="ABARAAPAPA"];
# 	"3c2325" [shape="point"];
# 	"a359da" -- "3c2325" [headlabel="ABARAAPAPAA"];
# 	"e8e86d" [label="ABARAAPAPAAD"];
# 	"3c2325" -- "e8e86d" ;
# 	"978561" [label="ABARAAPAPAAV"];
# 	"3c2325" -- "978561" ;
# 	"059ad1" [label="ABARAAPAPAP"];
# 	"a359da" -- "059ad1" ;
# 	"9f9e97" [shape="point"];
# 	"611ad0" -- "9f9e97" [headlabel="ABARAAPAPP"];
# 	"f05700" [label="ABARAAPAPPA"];
# 	"9f9e97" -- "f05700" ;
# 	"58215b" [label="ABARAAPAPPP"];
# 	"9f9e97" -- "58215b" ;
# 	"7d0b16" [shape="point"];
# 	"727d03" -- "7d0b16" [headlabel="ABARAAPP"];
# 	"088b29" [shape="point"];
# 	"7d0b16" -- "088b29" [headlabel="ABARAAPPA"];
# 	"9a5568" [shape="point"];
# 	"088b29" -- "9a5568" [headlabel="ABARAAPPAA"];
# 	"7f4a06" [label="ABARAAPPAAA"];
# 	"9a5568" -- "7f4a06" ;
# 	"e35a99" [label="ABARAAPPAAP"];
# 	"9a5568" -- "e35a99" ;
# 	"9bec97" [shape="point"];
# 	"088b29" -- "9bec97" [headlabel="ABARAAPPAP"];
# 	"9d67df" [label="ABARAAPPAPA"];
# 	"9bec97" -- "9d67df" ;
# 	"3b3b08" [label="ABARAAPPAPP"];
# 	"9bec97" -- "3b3b08" ;
# 	"6ab97d" [shape="point"];
# 	"7d0b16" -- "6ab97d" [headlabel="ABARAAPPP"];
# 	"ff14f5" [shape="point"];
# 	"6ab97d" -- "ff14f5" [headlabel="ABARAAPPPA"];
# 	"df9f27" [shape="point"];
# 	"ff14f5" -- "df9f27" [headlabel="ABARAAPPPAA"];
# 	"0bd7ba" [label="ABARAAPPPAAD"];
# 	"df9f27" -- "0bd7ba" ;
# 	"41c527" [label="ABARAAPPPAAV"];
# 	"df9f27" -- "41c527" ;
# 	"03e0a8" [label="ABARAAPPPAP"];
# 	"ff14f5" -- "03e0a8" ;
# 	"c420f1" [shape="point"];
# 	"6ab97d" -- "c420f1" [headlabel="ABARAAPPPP"];
# 	"2e9486" [label="ABARAAPPPPA"];
# 	"c420f1" -- "2e9486" ;
# 	"7829f9" [label="ABARAAPPPPP"];
# 	"c420f1" -- "7829f9" ;
# 	"494d1c" [shape="point"];
# 	"2bcfe0" -- "494d1c" [headlabel="ABARAP"];
# 	"ec907b" [shape="point"];
# 	"494d1c" -- "ec907b" [headlabel="ABARAPA"];
# 	"6ba26e" [shape="point"];
# 	"ec907b" -- "6ba26e" [headlabel="ABARAPAA"];
# 	"554077" [shape="point"];
# 	"6ba26e" -- "554077" [headlabel="ABARAPAAA"];
# 	"07e782" [shape="point"];
# 	"554077" -- "07e782" [headlabel="ABARAPAAAA"];
# 	"92c8c1" [label="ABARAPAAAAA"];
# 	"07e782" -- "92c8c1" ;
# 	"e3d7e1" [label="ABARAPAAAAP"];
# 	"07e782" -- "e3d7e1" ;
# 	"7e1102" [shape="point"];
# 	"554077" -- "7e1102" [headlabel="ABARAPAAAP"];
# 	"86eb72" [label="ABARAPAAAPA"];
# 	"7e1102" -- "86eb72" ;
# 	"2f93c3" [label="ABARAPAAAPP"];
# 	"7e1102" -- "2f93c3" ;
# 	"a6cd43" [shape="point"];
# 	"6ba26e" -- "a6cd43" [headlabel="ABARAPAAP"];
# 	"df8ab5" [shape="point"];
# 	"a6cd43" -- "df8ab5" [headlabel="ABARAPAAPA"];
# 	"b495c2" [label="ABARAPAAPAA"];
# 	"df8ab5" -- "b495c2" ;
# 	"777885" [label="ABARAPAAPAP"];
# 	"df8ab5" -- "777885" ;
# 	"c5f559" [shape="point"];
# 	"a6cd43" -- "c5f559" [headlabel="ABARAPAAPP"];
# 	"977683" [label="ABARAPAAPPA"];
# 	"c5f559" -- "977683" ;
# 	"3393ce" [label="ABARAPAAPPP"];
# 	"c5f559" -- "3393ce" ;
# 	"6c6dba" [shape="point"];
# 	"ec907b" -- "6c6dba" [headlabel="ABARAPAP"];
# 	"9252e5" [shape="point"];
# 	"6c6dba" -- "9252e5" [headlabel="ABARAPAPA"];
# 	"ff32f2" [shape="point"];
# 	"9252e5" -- "ff32f2" [headlabel="ABARAPAPAA"];
# 	"f9cd31" [label="ABARAPAPAAA"];
# 	"ff32f2" -- "f9cd31" ;
# 	"c268ab" [shape="point"];
# 	"ff32f2" -- "c268ab" [headlabel="ABARAPAPAAP"];
# 	"96b46c" [label="ABARAPAPAAPA"];
# 	"c268ab" -- "96b46c" ;
# 	"1628bf" [label="ABARAPAPAAPP"];
# 	"c268ab" -- "1628bf" ;
# 	"377e18" [shape="point"];
# 	"9252e5" -- "377e18" [headlabel="ABARAPAPAP"];
# 	"f19225" [label="ABARAPAPAPA"];
# 	"377e18" -- "f19225" ;
# 	"cb5252" [label="ABARAPAPAPP"];
# 	"377e18" -- "cb5252" ;
# 	"990dd0" [shape="point"];
# 	"6c6dba" -- "990dd0" [headlabel="ABARAPAPP"];
# 	"cdc161" [shape="point"];
# 	"990dd0" -- "cdc161" [headlabel="ABARAPAPPA"];
# 	"178eb3" [label="ABARAPAPPAA"];
# 	"cdc161" -- "178eb3" ;
# 	"e0b0d3" [label="ABARAPAPPAP"];
# 	"cdc161" -- "e0b0d3" ;
# 	"3130a7" [shape="point"];
# 	"990dd0" -- "3130a7" [headlabel="ABARAPAPPP"];
# 	"bf8aa2" [label="ABARAPAPPPA"];
# 	"3130a7" -- "bf8aa2" ;
# 	"55c658" [label="ABARAPAPPPP"];
# 	"3130a7" -- "55c658" ;
# 	"2249a3" [shape="point"];
# 	"494d1c" -- "2249a3" [headlabel="ABARAPP"];
# 	"8c9170" [shape="point"];
# 	"2249a3" -- "8c9170" [headlabel="ABARAPPA"];
# 	"1e1a18" [shape="point"];
# 	"8c9170" -- "1e1a18" [headlabel="ABARAPPAA"];
# 	"01cf67" [shape="point"];
# 	"1e1a18" -- "01cf67" [headlabel="ABARAPPAAA"];
# 	"895d3a" [label="ABARAPPAAAA"];
# 	"01cf67" -- "895d3a" ;
# 	"620247" [label="ABARAPPAAAP"];
# 	"01cf67" -- "620247" ;
# 	"719d51" [shape="point"];
# 	"1e1a18" -- "719d51" [headlabel="ABARAPPAAP"];
# 	"918afa" [label="ABARAPPAAPA"];
# 	"719d51" -- "918afa" ;
# 	"86e87b" [label="ABARAPPAAPP"];
# 	"719d51" -- "86e87b" ;
# 	"7be82f" [shape="point"];
# 	"8c9170" -- "7be82f" [headlabel="ABARAPPAP"];
# 	"8aca6a" [shape="point"];
# 	"7be82f" -- "8aca6a" [headlabel="ABARAPPAPA"];
# 	"e34998" [label="ABARAPPAPAA"];
# 	"8aca6a" -- "e34998" ;
# 	"42b792" [shape="point"];
# 	"8aca6a" -- "42b792" [headlabel="ABARAPPAPAP"];
# 	"609497" [label="ABARAPPAPAPA"];
# 	"42b792" -- "609497" ;
# 	"4f5f78" [label="ABARAPPAPAPP"];
# 	"42b792" -- "4f5f78" ;
# 	"841ffd" [shape="point"];
# 	"7be82f" -- "841ffd" [headlabel="ABARAPPAPP"];
# 	"97a412" [label="ABARAPPAPPA"];
# 	"841ffd" -- "97a412" ;
# 	"fed4dc" [label="ABARAPPAPPP"];
# 	"841ffd" -- "fed4dc" ;
# 	"686caf" [shape="point"];
# 	"2249a3" -- "686caf" [headlabel="ABARAPPP"];
# 	"09476c" [shape="point"];
# 	"686caf" -- "09476c" [headlabel="ABARAPPPA"];
# 	"89a301" [shape="point"];
# 	"09476c" -- "89a301" [headlabel="ABARAPPPAA"];
# 	"4fb91a" [label="ABARAPPPAAA"];
# 	"89a301" -- "4fb91a" ;
# 	"9abe79" [label="ABARAPPPAAP"];
# 	"89a301" -- "9abe79" ;
# 	"293d4e" [shape="point"];
# 	"09476c" -- "293d4e" [headlabel="ABARAPPPAP"];
# 	"084c22" [label="ABARAPPPAPA"];
# 	"293d4e" -- "084c22" ;
# 	"d15b94" [label="ABARAPPPAPP"];
# 	"293d4e" -- "d15b94" ;
# 	"925a9e" [shape="point"];
# 	"686caf" -- "925a9e" [headlabel="ABARAPPPP"];
# 	"3f5d53" [shape="point"];
# 	"925a9e" -- "3f5d53" [headlabel="ABARAPPPPA"];
# 	"2c0ad6" [label="ABARAPPPPAA"];
# 	"3f5d53" -- "2c0ad6" ;
# 	"d55efc" [label="ABARAPPPPAP"];
# 	"3f5d53" -- "d55efc" ;
# 	"eb6813" [shape="point"];
# 	"925a9e" -- "eb6813" [headlabel="ABARAPPPPP"];
# 	"fecb60" [shape="point"];
# 	"eb6813" -- "fecb60" [headlabel="ABARAPPPPPA"];
# 	"4bf81a" [label="ABARAPPPPPAA"];
# 	"fecb60" -- "4bf81a" ;
# 	"ec04cb" [label="ABARAPPPPPAP"];
# 	"fecb60" -- "ec04cb" ;
# 	"c7d2da" [label="ABARAPPPPPP"];
# 	"eb6813" -- "c7d2da" ;
# 	"66bcb2" [shape="point"];
# 	"a44401" -- "66bcb2" [headlabel="ABARP"];
# 	"9a0d3f" [shape="point"];
# 	"66bcb2" -- "9a0d3f" [headlabel="ABARPA"];
# 	"e18304" [shape="point"];
# 	"9a0d3f" -- "e18304" [headlabel="ABARPAA"];
# 	"8c7113" [shape="point"];
# 	"e18304" -- "8c7113" [headlabel="ABARPAAA"];
# 	"ae39fa" [shape="point"];
# 	"8c7113" -- "ae39fa" [headlabel="ABARPAAAA"];
# 	"cf7d30" [shape="point"];
# 	"ae39fa" -- "cf7d30" [headlabel="ABARPAAAAA"];
# 	"aec7c4" [label="ABARPAAAAAL"];
# 	"cf7d30" -- "aec7c4" ;
# 	"c6f092" [label="ABARPAAAAAR"];
# 	"cf7d30" -- "c6f092" ;
# 	"489dd2" [shape="point"];
# 	"ae39fa" -- "489dd2" [headlabel="ABARPAAAAP"];
# 	"c61ae1" [label="ABARPAAAAPA"];
# 	"489dd2" -- "c61ae1" ;
# 	"950104" [label="ABARPAAAAPP"];
# 	"489dd2" -- "950104" ;
# 	"3cb43a" [shape="point"];
# 	"8c7113" -- "3cb43a" [headlabel="ABARPAAAP"];
# 	"24328e" [shape="point"];
# 	"3cb43a" -- "24328e" [headlabel="ABARPAAAPA"];
# 	"b4fd54" [label="ABARPAAAPAA"];
# 	"24328e" -- "b4fd54" ;
# 	"07dc23" [label="ABARPAAAPAP"];
# 	"24328e" -- "07dc23" ;
# 	"d95e30" [label="ABARPAAAPP"];
# 	"3cb43a" -- "d95e30" ;
# 	"df0202" [shape="point"];
# 	"e18304" -- "df0202" [headlabel="ABARPAAP"];
# 	"45400c" [shape="point"];
# 	"df0202" -- "45400c" [headlabel="ABARPAAPA"];
# 	"8b80f7" [label="ABARPAAPAA"];
# 	"45400c" -- "8b80f7" ;
# 	"83339e" [label="ABARPAAPAP"];
# 	"45400c" -- "83339e" ;
# 	"a0f037" [shape="point"];
# 	"df0202" -- "a0f037" [headlabel="ABARPAAPP"];
# 	"f01743" [label="ABARPAAPPA"];
# 	"a0f037" -- "f01743" ;
# 	"d33e9a" [label="ABARPAAPPP"];
# 	"a0f037" -- "d33e9a" ;
# 	"e00048" [shape="point"];
# 	"9a0d3f" -- "e00048" [headlabel="ABARPAP"];
# 	"1a9c16" [shape="point"];
# 	"e00048" -- "1a9c16" [headlabel="ABARPAPA"];
# 	"72d9ce" [shape="point"];
# 	"1a9c16" -- "72d9ce" [headlabel="ABARPAPAA"];
# 	"0536eb" [shape="point"];
# 	"72d9ce" -- "0536eb" [headlabel="ABARPAPAAA"];
# 	"48d884" [label="ABARPAPAAAA"];
# 	"0536eb" -- "48d884" ;
# 	"276e30" [label="ABARPAPAAAP"];
# 	"0536eb" -- "276e30" ;
# 	"e0cd09" [shape="point"];
# 	"72d9ce" -- "e0cd09" [headlabel="ABARPAPAAP"];
# 	"9de1b2" [label="ABARPAPAAPA"];
# 	"e0cd09" -- "9de1b2" ;
# 	"82170d" [shape="point"];
# 	"e0cd09" -- "82170d" [headlabel="ABARPAPAAPP"];
# 	"66403b" [label="ABARPAPAAPPA"];
# 	"82170d" -- "66403b" ;
# 	"fe0938" [label="ABARPAPAAPPP"];
# 	"82170d" -- "fe0938" ;
# 	"f5f969" [shape="point"];
# 	"1a9c16" -- "f5f969" [headlabel="ABARPAPAP"];
# 	"fad157" [label="ABARPAPAPA"];
# 	"f5f969" -- "fad157" ;
# 	"85d9d7" [label="ABARPAPAPP"];
# 	"f5f969" -- "85d9d7" ;
# 	"c7ad99" [shape="point"];
# 	"e00048" -- "c7ad99" [headlabel="ABARPAPP"];
# 	"9cd22a" [shape="point"];
# 	"c7ad99" -- "9cd22a" [headlabel="ABARPAPPA"];
# 	"90ceac" [label="ABARPAPPAA"];
# 	"9cd22a" -- "90ceac" ;
# 	"f78ea4" [label="ABARPAPPAP"];
# 	"9cd22a" -- "f78ea4" ;
# 	"b25ac7" [shape="point"];
# 	"c7ad99" -- "b25ac7" [headlabel="ABARPAPPP"];
# 	"bb76f4" [label="ABARPAPPPA"];
# 	"b25ac7" -- "bb76f4" ;
# 	"401aa3" [label="ABARPAPPPP"];
# 	"b25ac7" -- "401aa3" ;
# 	"ea8a9f" [shape="point"];
# 	"66bcb2" -- "ea8a9f" [headlabel="ABARPP"];
# 	"9f2bd1" [shape="point"];
# 	"ea8a9f" -- "9f2bd1" [headlabel="ABARPPA"];
# 	"eb30a4" [shape="point"];
# 	"9f2bd1" -- "eb30a4" [headlabel="ABARPPAA"];
# 	"92d3ea" [shape="point"];
# 	"eb30a4" -- "92d3ea" [headlabel="ABARPPAAA"];
# 	"5db086" [label="ABARPPAAAA"];
# 	"92d3ea" -- "5db086" ;
# 	"f36208" [label="ABARPPAAAP"];
# 	"92d3ea" -- "f36208" ;
# 	"bd8458" [shape="point"];
# 	"eb30a4" -- "bd8458" [headlabel="ABARPPAAP"];
# 	"f7d9b6" [label="ABARPPAAPA"];
# 	"bd8458" -- "f7d9b6" ;
# 	"82fb45" [shape="point"];
# 	"bd8458" -- "82fb45" [headlabel="ABARPPAAPP"];
# 	"845e1d" [label="ABARPPAAPPA"];
# 	"82fb45" -- "845e1d" ;
# 	"b26d88" [label="ABARPPAAPPP"];
# 	"82fb45" -- "b26d88" ;
# 	"0ff19f" [shape="point"];
# 	"9f2bd1" -- "0ff19f" [headlabel="ABARPPAP"];
# 	"8ac007" [shape="point"];
# 	"0ff19f" -- "8ac007" [headlabel="ABARPPAPA"];
# 	"e2fc40" [label="ABARPPAPAA"];
# 	"8ac007" -- "e2fc40" ;
# 	"d12621" [label="ABARPPAPAP"];
# 	"8ac007" -- "d12621" ;
# 	"6bb642" [shape="point"];
# 	"0ff19f" -- "6bb642" [headlabel="ABARPPAPP"];
# 	"b391ed" [label="ABARPPAPPA"];
# 	"6bb642" -- "b391ed" ;
# 	"e61d75" [label="ABARPPAPPP"];
# 	"6bb642" -- "e61d75" ;
# 	"6226fe" [shape="point"];
# 	"ea8a9f" -- "6226fe" [headlabel="ABARPPP"];
# 	"0ba4cd" [shape="point"];
# 	"6226fe" -- "0ba4cd" [headlabel="ABARPPPA"];
# 	"b0152e" [shape="point"];
# 	"0ba4cd" -- "b0152e" [headlabel="ABARPPPAA"];
# 	"3f39eb" [label="ABARPPPAAA"];
# 	"b0152e" -- "3f39eb" ;
# 	"c4d267" [label="ABARPPPAAP"];
# 	"b0152e" -- "c4d267" ;
# 	"163b5a" [shape="point"];
# 	"0ba4cd" -- "163b5a" [headlabel="ABARPPPAP"];
# 	"796dee" [label="ABARPPPAPA"];
# 	"163b5a" -- "796dee" ;
# 	"84fe46" [shape="point"];
# 	"163b5a" -- "84fe46" [headlabel="ABARPPPAPP"];
# 	"19ce87" [label="ABARPPPAPPA"];
# 	"84fe46" -- "19ce87" ;
# 	"2004b6" [label="ABARPPPAPPP"];
# 	"84fe46" -- "2004b6" ;
# 	"f4ac6f" [shape="point"];
# 	"6226fe" -- "f4ac6f" [headlabel="ABARPPPP"];
# 	"7aa6bd" [shape="point"];
# 	"f4ac6f" -- "7aa6bd" [headlabel="ABARPPPPA"];
# 	"eb79c5" [label="ABARPPPPAA"];
# 	"7aa6bd" -- "eb79c5" ;
# 	"ecbc0d" [label="ABARPPPPAP"];
# 	"7aa6bd" -- "ecbc0d" ;
# 	"9d29b9" [shape="point"];
# 	"f4ac6f" -- "9d29b9" [headlabel="ABARPPPPP"];
# 	"f0ec9c" [label="ABARPPPPPA"];
# 	"9d29b9" -- "f0ec9c" ;
# 	"560ec8" [label="ABARPPPPPP"];
# 	"9d29b9" -- "560ec8" ;
# 	"1da042" [shape="point"];
# 	"9981a3" -- "1da042" [headlabel="ABP"];
# 	"761f50" [shape="point"];
# 	"1da042" -- "761f50" [headlabel="ABPL"];
# 	"cbe2ee" [shape="point"];
# 	"761f50" -- "cbe2ee" [headlabel="ABPLA"];
# 	"2b1caa" [shape="point"];
# 	"cbe2ee" -- "2b1caa" [headlabel="ABPLAA"];
# 	"55c59b" [shape="point"];
# 	"2b1caa" -- "55c59b" [headlabel="ABPLAAA"];
# 	"4833d3" [shape="point"];
# 	"55c59b" -- "4833d3" [headlabel="ABPLAAAA"];
# 	"ef5b16" [shape="point"];
# 	"4833d3" -- "ef5b16" [headlabel="ABPLAAAAA"];
# 	"f9d29e" [shape="point"];
# 	"ef5b16" -- "f9d29e" [headlabel="ABPLAAAAAA"];
# 	"01d10a" [label="ABPLAAAAAAA"];
# 	"f9d29e" -- "01d10a" ;
# 	"06d1de" [label="ABPLAAAAAAP"];
# 	"f9d29e" -- "06d1de" ;
# 	"1f3ac8" [shape="point"];
# 	"ef5b16" -- "1f3ac8" [headlabel="ABPLAAAAAP"];
# 	"d2d68c" [label="ABPLAAAAAPA"];
# 	"1f3ac8" -- "d2d68c" ;
# 	"44efc7" [shape="point"];
# 	"1f3ac8" -- "44efc7" [headlabel="ABPLAAAAAPP"];
# 	"a5dec0" [label="ABPLAAAAAPPA"];
# 	"44efc7" -- "a5dec0" ;
# 	"0911d0" [label="ABPLAAAAAPPP"];
# 	"44efc7" -- "0911d0" ;
# 	"2a6910" [shape="point"];
# 	"4833d3" -- "2a6910" [headlabel="ABPLAAAAP"];
# 	"a45c3e" [label="ABPLAAAAPA"];
# 	"2a6910" -- "a45c3e" ;
# 	"2393d5" [label="ABPLAAAAPP"];
# 	"2a6910" -- "2393d5" ;
# 	"b5d3fe" [shape="point"];
# 	"55c59b" -- "b5d3fe" [headlabel="ABPLAAAP"];
# 	"adac24" [shape="point"];
# 	"b5d3fe" -- "adac24" [headlabel="ABPLAAAPA"];
# 	"5dfc2c" [label="ABPLAAAPAA"];
# 	"adac24" -- "5dfc2c" ;
# 	"1c4362" [label="ABPLAAAPAP"];
# 	"adac24" -- "1c4362" ;
# 	"cb4e1b" [shape="point"];
# 	"b5d3fe" -- "cb4e1b" [headlabel="ABPLAAAPP"];
# 	"d5b923" [label="ABPLAAAPPA"];
# 	"cb4e1b" -- "d5b923" ;
# 	"ee900f" [label="ABPLAAAPPP"];
# 	"cb4e1b" -- "ee900f" ;
# 	"608061" [shape="point"];
# 	"2b1caa" -- "608061" [headlabel="ABPLAAP"];
# 	"bc93c4" [shape="point"];
# 	"608061" -- "bc93c4" [headlabel="ABPLAAPA"];
# 	"d7e76c" [shape="point"];
# 	"bc93c4" -- "d7e76c" [headlabel="ABPLAAPAA"];
# 	"9f2cc8" [shape="point"];
# 	"d7e76c" -- "9f2cc8" [headlabel="ABPLAAPAAA"];
# 	"fc451c" [label="ABPLAAPAAAA"];
# 	"9f2cc8" -- "fc451c" ;
# 	"d37540" [label="ABPLAAPAAAP"];
# 	"9f2cc8" -- "d37540" ;
# 	"d69129" [label="ABPLAAPAAP"];
# 	"d7e76c" -- "d69129" ;
# 	"80072c" [shape="point"];
# 	"bc93c4" -- "80072c" [headlabel="ABPLAAPAP"];
# 	"25544e" [shape="point"];
# 	"80072c" -- "25544e" [headlabel="ABPLAAPAPA"];
# 	"eea348" [label="ABPLAAPAPAA"];
# 	"25544e" -- "eea348" ;
# 	"04c4a4" [label="ABPLAAPAPAP"];
# 	"25544e" -- "04c4a4" ;
# 	"20356b" [shape="point"];
# 	"80072c" -- "20356b" [headlabel="ABPLAAPAPP"];
# 	"9744c5" [label="ABPLAAPAPPA"];
# 	"20356b" -- "9744c5" ;
# 	"84619b" [shape="point"];
# 	"20356b" -- "84619b" [headlabel="ABPLAAPAPPP"];
# 	"26afd7" [label="ABPLAAPAPPPA"];
# 	"84619b" -- "26afd7" ;
# 	"2e09f5" [label="ABPLAAPAPPPP"];
# 	"84619b" -- "2e09f5" ;
# 	"402430" [shape="point"];
# 	"608061" -- "402430" [headlabel="ABPLAAPP"];
# 	"7381c6" [shape="point"];
# 	"402430" -- "7381c6" [headlabel="ABPLAAPPA"];
# 	"206faa" [label="ABPLAAPPAA"];
# 	"7381c6" -- "206faa" ;
# 	"66ef59" [label="ABPLAAPPAP"];
# 	"7381c6" -- "66ef59" ;
# 	"419cb4" [shape="point"];
# 	"402430" -- "419cb4" [headlabel="ABPLAAPPP"];
# 	"ac3ff7" [label="ABPLAAPPPA"];
# 	"419cb4" -- "ac3ff7" ;
# 	"1aa3c4" [label="ABPLAAPPPP"];
# 	"419cb4" -- "1aa3c4" ;
# 	"386402" [shape="point"];
# 	"cbe2ee" -- "386402" [headlabel="ABPLAP"];
# 	"4d1363" [shape="point"];
# 	"386402" -- "4d1363" [headlabel="ABPLAPA"];
# 	"bbe9b1" [shape="point"];
# 	"4d1363" -- "bbe9b1" [headlabel="ABPLAPAA"];
# 	"9204c3" [shape="point"];
# 	"bbe9b1" -- "9204c3" [headlabel="ABPLAPAAA"];
# 	"44f2a5" [shape="point"];
# 	"9204c3" -- "44f2a5" [headlabel="ABPLAPAAAA"];
# 	"8b3600" [label="ABPLAPAAAAA"];
# 	"44f2a5" -- "8b3600" ;
# 	"da39d3" [shape="point"];
# 	"44f2a5" -- "da39d3" [headlabel="ABPLAPAAAAP"];
# 	"69fd0e" [label="ABPLAPAAAAPA"];
# 	"da39d3" -- "69fd0e" ;
# 	"662178" [label="ABPLAPAAAAPP"];
# 	"da39d3" -- "662178" ;
# 	"944d72" [shape="point"];
# 	"9204c3" -- "944d72" [headlabel="ABPLAPAAAP"];
# 	"64a6cd" [shape="point"];
# 	"944d72" -- "64a6cd" [headlabel="ABPLAPAAAPA"];
# 	"b83d80" [label="ABPLAPAAAPAD"];
# 	"64a6cd" -- "b83d80" ;
# 	"3252a9" [label="ABPLAPAAAPAV"];
# 	"64a6cd" -- "3252a9" ;
# 	"bf4d6d" [label="ABPLAPAAAPP"];
# 	"944d72" -- "bf4d6d" ;
# 	"7366e1" [shape="point"];
# 	"bbe9b1" -- "7366e1" [headlabel="ABPLAPAAP"];
# 	"d050b9" [label="ABPLAPAAPA"];
# 	"7366e1" -- "d050b9" ;
# 	"cde659" [label="ABPLAPAAPP"];
# 	"7366e1" -- "cde659" ;
# 	"237439" [shape="point"];
# 	"4d1363" -- "237439" [headlabel="ABPLAPAP"];
# 	"04d04a" [shape="point"];
# 	"237439" -- "04d04a" [headlabel="ABPLAPAPA"];
# 	"cd6f92" [shape="point"];
# 	"04d04a" -- "cd6f92" [headlabel="ABPLAPAPAA"];
# 	"d0913b" [label="ABPLAPAPAAA"];
# 	"cd6f92" -- "d0913b" ;
# 	"6a3158" [label="ABPLAPAPAAP"];
# 	"cd6f92" -- "6a3158" ;
# 	"8ac1f8" [label="ABPLAPAPAP"];
# 	"04d04a" -- "8ac1f8" ;
# 	"fd7a75" [shape="point"];
# 	"237439" -- "fd7a75" [headlabel="ABPLAPAPP"];
# 	"2b94c1" [label="ABPLAPAPPA"];
# 	"fd7a75" -- "2b94c1" ;
# 	"86af0e" [shape="point"];
# 	"fd7a75" -- "86af0e" [headlabel="ABPLAPAPPP"];
# 	"3c936d" [label="ABPLAPAPPPA"];
# 	"86af0e" -- "3c936d" ;
# 	"81eb57" [shape="point"];
# 	"86af0e" -- "81eb57" [headlabel="ABPLAPAPPPP"];
# 	"c95182" [shape="point"];
# 	"81eb57" -- "c95182" [headlabel="ABPLAPAPPPPA"];
# 	"2173a3" [label="ABPLAPAPPPPAA"];
# 	"c95182" -- "2173a3" ;
# 	"39f8ff" [label="ABPLAPAPPPPAP"];
# 	"c95182" -- "39f8ff" ;
# 	"96898e" [label="ABPLAPAPPPPP"];
# 	"81eb57" -- "96898e" ;
# 	"4e7646" [shape="point"];
# 	"386402" -- "4e7646" [headlabel="ABPLAPP"];
# 	"d2248b" [shape="point"];
# 	"4e7646" -- "d2248b" [headlabel="ABPLAPPA"];
# 	"18bfe0" [shape="point"];
# 	"d2248b" -- "18bfe0" [headlabel="ABPLAPPAA"];
# 	"d703b4" [label="ABPLAPPAAA"];
# 	"18bfe0" -- "d703b4" ;
# 	"430c53" [label="ABPLAPPAAP"];
# 	"18bfe0" -- "430c53" ;
# 	"a3d0d2" [shape="point"];
# 	"d2248b" -- "a3d0d2" [headlabel="ABPLAPPAP"];
# 	"7786e9" [label="ABPLAPPAPA"];
# 	"a3d0d2" -- "7786e9" ;
# 	"6f80af" [label="ABPLAPPAPP"];
# 	"a3d0d2" -- "6f80af" ;
# 	"b3e0f6" [shape="point"];
# 	"4e7646" -- "b3e0f6" [headlabel="ABPLAPPP"];
# 	"5da1cc" [shape="point"];
# 	"b3e0f6" -- "5da1cc" [headlabel="ABPLAPPPA"];
# 	"5bedc9" [shape="point"];
# 	"5da1cc" -- "5bedc9" [headlabel="ABPLAPPPAA"];
# 	"81fd50" [label="ABPLAPPPAAA"];
# 	"5bedc9" -- "81fd50" ;
# 	"6ff23f" [label="ABPLAPPPAAP"];
# 	"5bedc9" -- "6ff23f" ;
# 	"6d1603" [shape="point"];
# 	"5da1cc" -- "6d1603" [headlabel="ABPLAPPPAP"];
# 	"c3e31c" [label="ABPLAPPPAPA"];
# 	"6d1603" -- "c3e31c" ;
# 	"2ee5f3" [shape="point"];
# 	"6d1603" -- "2ee5f3" [headlabel="ABPLAPPPAPP"];
# 	"fc9182" [label="ABPLAPPPAPPA"];
# 	"2ee5f3" -- "fc9182" ;
# 	"8628cb" [label="ABPLAPPPAPPP"];
# 	"2ee5f3" -- "8628cb" ;
# 	"f0c8ef" [shape="point"];
# 	"b3e0f6" -- "f0c8ef" [headlabel="ABPLAPPPP"];
# 	"42bf35" [label="ABPLAPPPPA"];
# 	"f0c8ef" -- "42bf35" ;
# 	"5f0027" [label="ABPLAPPPPP"];
# 	"f0c8ef" -- "5f0027" ;
# 	"3f9ca7" [shape="point"];
# 	"761f50" -- "3f9ca7" [headlabel="ABPLP"];
# 	"a642a6" [shape="point"];
# 	"3f9ca7" -- "a642a6" [headlabel="ABPLPA"];
# 	"a1b66f" [shape="point"];
# 	"a642a6" -- "a1b66f" [headlabel="ABPLPAA"];
# 	"b9290a" [shape="point"];
# 	"a1b66f" -- "b9290a" [headlabel="ABPLPAAA"];
# 	"d7c1f0" [shape="point"];
# 	"b9290a" -- "d7c1f0" [headlabel="ABPLPAAAA"];
# 	"2ee204" [shape="point"];
# 	"d7c1f0" -- "2ee204" [headlabel="ABPLPAAAAA"];
# 	"5ffd8d" [label="ABPLPAAAAAA"];
# 	"2ee204" -- "5ffd8d" ;
# 	"222bf3" [label="ABPLPAAAAAP"];
# 	"2ee204" -- "222bf3" ;
# 	"747f03" [shape="point"];
# 	"d7c1f0" -- "747f03" [headlabel="ABPLPAAAAP"];
# 	"402d17" [label="ABPLPAAAAPA"];
# 	"747f03" -- "402d17" ;
# 	"bb4265" [label="ABPLPAAAAPP"];
# 	"747f03" -- "bb4265" ;
# 	"534aa3" [shape="point"];
# 	"b9290a" -- "534aa3" [headlabel="ABPLPAAAP"];
# 	"e551c8" [shape="point"];
# 	"534aa3" -- "e551c8" [headlabel="ABPLPAAAPA"];
# 	"c3bcbf" [label="ABPLPAAAPAA"];
# 	"e551c8" -- "c3bcbf" ;
# 	"3d9231" [label="ABPLPAAAPAP"];
# 	"e551c8" -- "3d9231" ;
# 	"1e5b51" [shape="point"];
# 	"534aa3" -- "1e5b51" [headlabel="ABPLPAAAPP"];
# 	"e9f61a" [shape="point"];
# 	"1e5b51" -- "e9f61a" [headlabel="ABPLPAAAPPA"];
# 	"3c8cb6" [label="ABPLPAAAPPAA"];
# 	"e9f61a" -- "3c8cb6" ;
# 	"5e21da" [label="ABPLPAAAPPAP"];
# 	"e9f61a" -- "5e21da" ;
# 	"465589" [label="ABPLPAAAPPP"];
# 	"1e5b51" -- "465589" ;
# 	"47f51b" [shape="point"];
# 	"a1b66f" -- "47f51b" [headlabel="ABPLPAAP"];
# 	"ad1083" [shape="point"];
# 	"47f51b" -- "ad1083" [headlabel="ABPLPAAPA"];
# 	"be92f8" [shape="point"];
# 	"ad1083" -- "be92f8" [headlabel="ABPLPAAPAA"];
# 	"49fb89" [label="ABPLPAAPAAA"];
# 	"be92f8" -- "49fb89" ;
# 	"3707f8" [label="ABPLPAAPAAP"];
# 	"be92f8" -- "3707f8" ;
# 	"82338f" [shape="point"];
# 	"ad1083" -- "82338f" [headlabel="ABPLPAAPAP"];
# 	"61bd82" [label="ABPLPAAPAPA"];
# 	"82338f" -- "61bd82" ;
# 	"b3538a" [label="ABPLPAAPAPP"];
# 	"82338f" -- "b3538a" ;
# 	"6db3e0" [shape="point"];
# 	"47f51b" -- "6db3e0" [headlabel="ABPLPAAPP"];
# 	"4fd464" [shape="point"];
# 	"6db3e0" -- "4fd464" [headlabel="ABPLPAAPPA"];
# 	"5b1e69" [label="ABPLPAAPPAA"];
# 	"4fd464" -- "5b1e69" ;
# 	"00a0a4" [label="ABPLPAAPPAP"];
# 	"4fd464" -- "00a0a4" ;
# 	"34efae" [shape="point"];
# 	"6db3e0" -- "34efae" [headlabel="ABPLPAAPPP"];
# 	"1fab63" [label="ABPLPAAPPPA"];
# 	"34efae" -- "1fab63" ;
# 	"710fb9" [shape="point"];
# 	"34efae" -- "710fb9" [headlabel="ABPLPAAPPPP"];
# 	"a3eff3" [label="ABPLPAAPPPPA"];
# 	"710fb9" -- "a3eff3" ;
# 	"4d78b3" [label="ABPLPAAPPPPP"];
# 	"710fb9" -- "4d78b3" ;
# 	"869b8a" [shape="point"];
# 	"a642a6" -- "869b8a" [headlabel="ABPLPAP"];
# 	"ef5de0" [shape="point"];
# 	"869b8a" -- "ef5de0" [headlabel="ABPLPAPA"];
# 	"ae8dd8" [shape="point"];
# 	"ef5de0" -- "ae8dd8" [headlabel="ABPLPAPAA"];
# 	"e7e42b" [shape="point"];
# 	"ae8dd8" -- "e7e42b" [headlabel="ABPLPAPAAA"];
# 	"dfb652" [label="ABPLPAPAAAA"];
# 	"e7e42b" -- "dfb652" ;
# 	"182938" [label="ABPLPAPAAAP"];
# 	"e7e42b" -- "182938" ;
# 	"94d1f7" [shape="point"];
# 	"ae8dd8" -- "94d1f7" [headlabel="ABPLPAPAAP"];
# 	"6a9653" [label="ABPLPAPAAPA"];
# 	"94d1f7" -- "6a9653" ;
# 	"f37edf" [label="ABPLPAPAAPP"];
# 	"94d1f7" -- "f37edf" ;
# 	"7583f4" [shape="point"];
# 	"ef5de0" -- "7583f4" [headlabel="ABPLPAPAP"];
# 	"6c3944" [shape="point"];
# 	"7583f4" -- "6c3944" [headlabel="ABPLPAPAPA"];
# 	"e32bd6" [label="ABPLPAPAPAA"];
# 	"6c3944" -- "e32bd6" ;
# 	"063129" [label="ABPLPAPAPAP"];
# 	"6c3944" -- "063129" ;
# 	"10a4f4" [shape="point"];
# 	"7583f4" -- "10a4f4" [headlabel="ABPLPAPAPP"];
# 	"2b4ab8" [label="ABPLPAPAPPA"];
# 	"10a4f4" -- "2b4ab8" ;
# 	"aa1c8d" [label="ABPLPAPAPPP"];
# 	"10a4f4" -- "aa1c8d" ;
# 	"d2372e" [shape="point"];
# 	"869b8a" -- "d2372e" [headlabel="ABPLPAPP"];
# 	"d78307" [shape="point"];
# 	"d2372e" -- "d78307" [headlabel="ABPLPAPPA"];
# 	"d09d61" [shape="point"];
# 	"d78307" -- "d09d61" [headlabel="ABPLPAPPAA"];
# 	"f65c20" [label="ABPLPAPPAAA"];
# 	"d09d61" -- "f65c20" ;
# 	"f0a96d" [label="ABPLPAPPAAP"];
# 	"d09d61" -- "f0a96d" ;
# 	"906739" [label="ABPLPAPPAP"];
# 	"d78307" -- "906739" ;
# 	"ad04a2" [shape="point"];
# 	"d2372e" -- "ad04a2" [headlabel="ABPLPAPPP"];
# 	"e1595a" [shape="point"];
# 	"ad04a2" -- "e1595a" [headlabel="ABPLPAPPPA"];
# 	"4a178c" [label="ABPLPAPPPAA"];
# 	"e1595a" -- "4a178c" ;
# 	"0e2ece" [label="ABPLPAPPPAP"];
# 	"e1595a" -- "0e2ece" ;
# 	"75c872" [shape="point"];
# 	"ad04a2" -- "75c872" [headlabel="ABPLPAPPPP"];
# 	"d35d51" [label="ABPLPAPPPPA"];
# 	"75c872" -- "d35d51" ;
# 	"b4919d" [label="ABPLPAPPPPP"];
# 	"75c872" -- "b4919d" ;
# 	"7243ca" [shape="point"];
# 	"3f9ca7" -- "7243ca" [headlabel="ABPLPP"];
# 	"5ee0d6" [shape="point"];
# 	"7243ca" -- "5ee0d6" [headlabel="ABPLPPA"];
# 	"35a414" [shape="point"];
# 	"5ee0d6" -- "35a414" [headlabel="ABPLPPAA"];
# 	"df656d" [shape="point"];
# 	"35a414" -- "df656d" [headlabel="ABPLPPAAA"];
# 	"0011d8" [shape="point"];
# 	"df656d" -- "0011d8" [headlabel="ABPLPPAAAA"];
# 	"f4c726" [label="ABPLPPAAAAA"];
# 	"0011d8" -- "f4c726" ;
# 	"b1d6a1" [shape="point"];
# 	"0011d8" -- "b1d6a1" [headlabel="ABPLPPAAAAP"];
# 	"aa5329" [label="ABPLPPAAAAPA"];
# 	"b1d6a1" -- "aa5329" ;
# 	"ae75ca" [label="ABPLPPAAAAPP"];
# 	"b1d6a1" -- "ae75ca" ;
# 	"0f6aa5" [label="ABPLPPAAAP"];
# 	"df656d" -- "0f6aa5" ;
# 	"c2971e" [shape="point"];
# 	"35a414" -- "c2971e" [headlabel="ABPLPPAAP"];
# 	"85c9ac" [shape="point"];
# 	"c2971e" -- "85c9ac" [headlabel="ABPLPPAAPA"];
# 	"810a2c" [label="ABPLPPAAPAA"];
# 	"85c9ac" -- "810a2c" ;
# 	"931a2f" [label="ABPLPPAAPAP"];
# 	"85c9ac" -- "931a2f" ;
# 	"7e2ea3" [shape="point"];
# 	"c2971e" -- "7e2ea3" [headlabel="ABPLPPAAPP"];
# 	"702f90" [label="ABPLPPAAPPA"];
# 	"7e2ea3" -- "702f90" ;
# 	"214ae9" [label="ABPLPPAAPPP"];
# 	"7e2ea3" -- "214ae9" ;
# 	"8cd5bb" [shape="point"];
# 	"5ee0d6" -- "8cd5bb" [headlabel="ABPLPPAP"];
# 	"e4d8bc" [shape="point"];
# 	"8cd5bb" -- "e4d8bc" [headlabel="ABPLPPAPA"];
# 	"e8ca2b" [shape="point"];
# 	"e4d8bc" -- "e8ca2b" [headlabel="ABPLPPAPAA"];
# 	"a1f6f0" [shape="point"];
# 	"e8ca2b" -- "a1f6f0" [headlabel="ABPLPPAPAAA"];
# 	"6c8e2d" [label="ABPLPPAPAAAA"];
# 	"a1f6f0" -- "6c8e2d" ;
# 	"ff41c7" [label="ABPLPPAPAAAP"];
# 	"a1f6f0" -- "ff41c7" ;
# 	"4753f8" [label="ABPLPPAPAAP"];
# 	"e8ca2b" -- "4753f8" ;
# 	"e99a53" [shape="point"];
# 	"e4d8bc" -- "e99a53" [headlabel="ABPLPPAPAP"];
# 	"bb70df" [label="ABPLPPAPAPA"];
# 	"e99a53" -- "bb70df" ;
# 	"106b7d" [label="ABPLPPAPAPP"];
# 	"e99a53" -- "106b7d" ;
# 	"269f1f" [shape="point"];
# 	"8cd5bb" -- "269f1f" [headlabel="ABPLPPAPP"];
# 	"a5efad" [shape="point"];
# 	"269f1f" -- "a5efad" [headlabel="ABPLPPAPPA"];
# 	"ed5dda" [label="ABPLPPAPPAA"];
# 	"a5efad" -- "ed5dda" ;
# 	"3fc64d" [label="ABPLPPAPPAP"];
# 	"a5efad" -- "3fc64d" ;
# 	"ef9033" [shape="point"];
# 	"269f1f" -- "ef9033" [headlabel="ABPLPPAPPP"];
# 	"94cbe5" [label="ABPLPPAPPPA"];
# 	"ef9033" -- "94cbe5" ;
# 	"fbcd7d" [label="ABPLPPAPPPP"];
# 	"ef9033" -- "fbcd7d" ;
# 	"0eda22" [shape="point"];
# 	"7243ca" -- "0eda22" [headlabel="ABPLPPP"];
# 	"bcab54" [shape="point"];
# 	"0eda22" -- "bcab54" [headlabel="ABPLPPPA"];
# 	"f083b2" [shape="point"];
# 	"bcab54" -- "f083b2" [headlabel="ABPLPPPAA"];
# 	"863312" [shape="point"];
# 	"f083b2" -- "863312" [headlabel="ABPLPPPAAA"];
# 	"f0d847" [label="ABPLPPPAAAA"];
# 	"863312" -- "f0d847" ;
# 	"d67ed3" [label="ABPLPPPAAAP"];
# 	"863312" -- "d67ed3" ;
# 	"6d0404" [shape="point"];
# 	"f083b2" -- "6d0404" [headlabel="ABPLPPPAAP"];
# 	"67e7ef" [shape="point"];
# 	"6d0404" -- "67e7ef" [headlabel="ABPLPPPAAPA"];
# 	"64b13f" [label="ABPLPPPAAPAA"];
# 	"67e7ef" -- "64b13f" ;
# 	"92d042" [label="ABPLPPPAAPAP"];
# 	"67e7ef" -- "92d042" ;
# 	"01c47a" [label="ABPLPPPAAPP"];
# 	"6d0404" -- "01c47a" ;
# 	"c2b605" [shape="point"];
# 	"bcab54" -- "c2b605" [headlabel="ABPLPPPAP"];
# 	"54f12a" [shape="point"];
# 	"c2b605" -- "54f12a" [headlabel="ABPLPPPAPA"];
# 	"b8f18e" [label="ABPLPPPAPAA"];
# 	"54f12a" -- "b8f18e" ;
# 	"86edc6" [label="ABPLPPPAPAP"];
# 	"54f12a" -- "86edc6" ;
# 	"ef9d58" [label="ABPLPPPAPP"];
# 	"c2b605" -- "ef9d58" ;
# 	"420675" [shape="point"];
# 	"0eda22" -- "420675" [headlabel="ABPLPPPP"];
# 	"b70485" [shape="point"];
# 	"420675" -- "b70485" [headlabel="ABPLPPPPA"];
# 	"94c522" [shape="point"];
# 	"b70485" -- "94c522" [headlabel="ABPLPPPPAA"];
# 	"675eb2" [label="ABPLPPPPAAA"];
# 	"94c522" -- "675eb2" ;
# 	"27ab69" [label="ABPLPPPPAAP"];
# 	"94c522" -- "27ab69" ;
# 	"49d714" [shape="point"];
# 	"b70485" -- "49d714" [headlabel="ABPLPPPPAP"];
# 	"a7de3c" [label="ABPLPPPPAPA"];
# 	"49d714" -- "a7de3c" ;
# 	"a9f266" [label="ABPLPPPPAPP"];
# 	"49d714" -- "a9f266" ;
# 	"44f1e4" [shape="point"];
# 	"420675" -- "44f1e4" [headlabel="ABPLPPPPP"];
# 	"0b5b70" [shape="point"];
# 	"44f1e4" -- "0b5b70" [headlabel="ABPLPPPPPA"];
# 	"361e57" [label="ABPLPPPPPAA"];
# 	"0b5b70" -- "361e57" ;
# 	"87e272" [label="ABPLPPPPPAP"];
# 	"0b5b70" -- "87e272" ;
# 	"5d3b1d" [shape="point"];
# 	"44f1e4" -- "5d3b1d" [headlabel="ABPLPPPPPP"];
# 	"109644" [label="ABPLPPPPPPA"];
# 	"5d3b1d" -- "109644" ;
# 	"6dedb1" [label="ABPLPPPPPPP"];
# 	"5d3b1d" -- "6dedb1" ;
# 	"c352f4" [shape="point"];
# 	"1da042" -- "c352f4" [headlabel="ABPR"];
# 	"771cef" [shape="point"];
# 	"c352f4" -- "771cef" [headlabel="ABPRA"];
# 	"75f18f" [shape="point"];
# 	"771cef" -- "75f18f" [headlabel="ABPRAA"];
# 	"bc2377" [shape="point"];
# 	"75f18f" -- "bc2377" [headlabel="ABPRAAA"];
# 	"cd18dc" [shape="point"];
# 	"bc2377" -- "cd18dc" [headlabel="ABPRAAAA"];
# 	"66dd7b" [shape="point"];
# 	"cd18dc" -- "66dd7b" [headlabel="ABPRAAAAA"];
# 	"9bd19d" [shape="point"];
# 	"66dd7b" -- "9bd19d" [headlabel="ABPRAAAAAA"];
# 	"16b75e" [label="ABPRAAAAAAA"];
# 	"9bd19d" -- "16b75e" ;
# 	"14e771" [label="ABPRAAAAAAP"];
# 	"9bd19d" -- "14e771" ;
# 	"1a19a6" [shape="point"];
# 	"66dd7b" -- "1a19a6" [headlabel="ABPRAAAAAP"];
# 	"e12e66" [label="ABPRAAAAAPD"];
# 	"1a19a6" -- "e12e66" ;
# 	"b3289e" [label="ABPRAAAAAPV"];
# ...
# 	"6da1fe" [shape="point"];
# 	"636592" -- "6da1fe" [headlabel="MSAPAAAA"];
# 	"9645d2" [label="MSAPAAAAD"];
# 	"6da1fe" -- "9645d2" ;
# 	"84d175" [label="MSAPAAAAV"];
# 	"6da1fe" -- "84d175" ;
# 	"029f21" [label="MSAPAAAP"];
# 	"636592" -- "029f21" ;
# 	"6e3b59" [label="MSAPAAP"];
# 	"0cb4c4" -- "6e3b59" ;
# 	"180c38" [shape="point"];
# 	"bd65ee" -- "180c38" [headlabel="MSAPAP"];
# 	"30af65" [shape="point"];
# 	"180c38" -- "30af65" [headlabel="MSAPAPA"];
# 	"3a60ff" [shape="point"];
# 	"30af65" -- "3a60ff" [headlabel="MSAPAPAA"];
# 	"e3c0c1" [label="MSAPAPAAA"];
# 	"3a60ff" -- "e3c0c1" ;
# 	"a0a779" [label="MSAPAPAAP"];
# 	"3a60ff" -- "a0a779" ;
# 	"08a3a2" [label="MSAPAPAP"];
# 	"30af65" -- "08a3a2" ;
# 	"ed396d" [shape="point"];
# 	"180c38" -- "ed396d" [headlabel="MSAPAPP"];
# 	"525ba5" [label="MSAPAPPA"];
# 	"ed396d" -- "525ba5" ;
# 	"7d2eb7" [label="MSAPAPPP"];
# 	"ed396d" -- "7d2eb7" ;
# 	"bfdefb" [shape="point"];
# 	"83d46a" -- "bfdefb" [headlabel="MSAPP"];
# 	"2413e1" [shape="point"];
# 	"bfdefb" -- "2413e1" [headlabel="MSAPPA"];
# 	"02fa70" [shape="point"];
# 	"2413e1" -- "02fa70" [headlabel="MSAPPAA"];
# 	"6ee4d0" [label="MSAPPAAA"];
# 	"02fa70" -- "6ee4d0" ;
# 	"709cb8" [label="MSAPPAAP"];
# 	"02fa70" -- "709cb8" ;
# 	"5b33ae" [shape="point"];
# 	"2413e1" -- "5b33ae" [headlabel="MSAPPAP"];
# 	"8d388a" [label="MSAPPAPA"];
# 	"5b33ae" -- "8d388a" ;
# 	"9dfbb7" [label="MSAPPAPP"];
# 	"5b33ae" -- "9dfbb7" ;
# 	"e4fa59" [shape="point"];
# 	"bfdefb" -- "e4fa59" [headlabel="MSAPPP"];
# 	"0f8976" [shape="point"];
# 	"e4fa59" -- "0f8976" [headlabel="MSAPPPA"];
# 	"cc4529" [label="MSAPPPAA"];
# 	"0f8976" -- "cc4529" ;
# 	"318208" [label="MSAPPPAP"];
# 	"0f8976" -- "318208" ;
# 	"488911" [shape="point"];
# 	"e4fa59" -- "488911" [headlabel="MSAPPPP"];
# 	"91bd8b" [label="MSAPPPPA"];
# 	"488911" -- "91bd8b" ;
# 	"ca4b4c" [label="MSAPPPPP"];
# 	"488911" -- "ca4b4c" ;
# 	"e4b289" [shape="point"];
# 	"76b0a4" -- "e4b289" [headlabel="MSP"];
# 	"0e8077" [shape="point"];
# 	"e4b289" -- "0e8077" [headlabel="MSPA"];
# 	"008fa4" [shape="point"];
# 	"0e8077" -- "008fa4" [headlabel="MSPAA"];
# 	"10c0c5" [shape="point"];
# 	"008fa4" -- "10c0c5" [headlabel="MSPAAA"];
# 	"b6a426" [shape="point"];
# 	"10c0c5" -- "b6a426" [headlabel="MSPAAAA"];
# 	"51133f" [shape="point"];
# 	"b6a426" -- "51133f" [headlabel="MSPAAAAA"];
# 	"f515f2" [label="MSPAAAAAA"];
# 	"51133f" -- "f515f2" ;
# 	"b7cd79" [label="MSPAAAAAP"];
# 	"51133f" -- "b7cd79" ;
# 	"e1ec2c" [shape="point"];
# 	"b6a426" -- "e1ec2c" [headlabel="MSPAAAAP"];
# 	"0d0fa4" [label="MSPAAAAPA"];
# 	"e1ec2c" -- "0d0fa4" ;
# 	"9bd2eb" [label="MSPAAAAPP"];
# 	"e1ec2c" -- "9bd2eb" ;
# 	"9ac7c9" [shape="point"];
# 	"10c0c5" -- "9ac7c9" [headlabel="MSPAAAP"];
# 	"94d3e4" [shape="point"];
# 	"9ac7c9" -- "94d3e4" [headlabel="MSPAAAPA"];
# 	"d2379e" [label="MSPAAAPAA"];
# 	"94d3e4" -- "d2379e" ;
# 	"945aee" [label="MSPAAAPAP"];
# 	"94d3e4" -- "945aee" ;
# 	"45f42f" [shape="point"];
# 	"9ac7c9" -- "45f42f" [headlabel="MSPAAAPP"];
# 	"2065bd" [label="MSPAAAPPA"];
# 	"45f42f" -- "2065bd" ;
# 	"6ef521" [label="MSPAAAPPP"];
# 	"45f42f" -- "6ef521" ;
# 	"16f894" [shape="point"];
# 	"008fa4" -- "16f894" [headlabel="MSPAAP"];
# 	"80c2c4" [shape="point"];
# 	"16f894" -- "80c2c4" [headlabel="MSPAAPA"];
# 	"d58aea" [shape="point"];
# 	"80c2c4" -- "d58aea" [headlabel="MSPAAPAA"];
# 	"e00e3c" [label="MSPAAPAAA"];
# 	"d58aea" -- "e00e3c" ;
# 	"3938b9" [label="MSPAAPAAP"];
# 	"d58aea" -- "3938b9" ;
# 	"edf210" [shape="point"];
# 	"80c2c4" -- "edf210" [headlabel="MSPAAPAP"];
# 	"0705e5" [label="MSPAAPAPA"];
# 	"edf210" -- "0705e5" ;
# 	"6eb1fa" [label="MSPAAPAPP"];
# 	"edf210" -- "6eb1fa" ;
# 	"702090" [label="MSPAAPP"];
# 	"16f894" -- "702090" ;
# 	"f322b1" [shape="point"];
# 	"0e8077" -- "f322b1" [headlabel="MSPAP"];
# 	"5ba19a" [shape="point"];
# 	"f322b1" -- "5ba19a" [headlabel="MSPAPA"];
# 	"587681" [shape="point"];
# 	"5ba19a" -- "587681" [headlabel="MSPAPAA"];
# 	"ed6f79" [shape="point"];
# 	"587681" -- "ed6f79" [headlabel="MSPAPAAA"];
# 	"5f3e6b" [label="MSPAPAAAA"];
# 	"ed6f79" -- "5f3e6b" ;
# 	"802c9a" [label="MSPAPAAAP"];
# 	"ed6f79" -- "802c9a" ;
# 	"1e3c57" [shape="point"];
# 	"587681" -- "1e3c57" [headlabel="MSPAPAAP"];
# 	"ec4d24" [shape="point"];
# 	"1e3c57" -- "ec4d24" [headlabel="MSPAPAAPA"];
# 	"2b4081" [label="MSPAPAAPAA"];
# 	"ec4d24" -- "2b4081" ;
# 	"efc275" [label="MSPAPAAPAP"];
# 	"ec4d24" -- "efc275" ;
# 	"03b14c" [label="MSPAPAAPP"];
# 	"1e3c57" -- "03b14c" ;
# 	"c82e3b" [shape="point"];
# 	"5ba19a" -- "c82e3b" [headlabel="MSPAPAP"];
# 	"ba90f0" [shape="point"];
# 	"c82e3b" -- "ba90f0" [headlabel="MSPAPAPA"];
# 	"947615" [label="MSPAPAPAA"];
# 	"ba90f0" -- "947615" ;
# 	"a02e60" [label="MSPAPAPAP"];
# 	"ba90f0" -- "a02e60" ;
# 	"6a9ba1" [shape="point"];
# 	"c82e3b" -- "6a9ba1" [headlabel="MSPAPAPP"];
# 	"a7d87b" [label="MSPAPAPPA"];
# 	"6a9ba1" -- "a7d87b" ;
# 	"1be676" [label="MSPAPAPPP"];
# 	"6a9ba1" -- "1be676" ;
# 	"7cdcdb" [shape="point"];
# 	"f322b1" -- "7cdcdb" [headlabel="MSPAPP"];
# 	"398121" [shape="point"];
# 	"7cdcdb" -- "398121" [headlabel="MSPAPPA"];
# 	"7e0a17" [label="MSPAPPAA"];
# 	"398121" -- "7e0a17" ;
# 	"2d5529" [label="MSPAPPAP"];
# 	"398121" -- "2d5529" ;
# 	"4a89c8" [shape="point"];
# 	"7cdcdb" -- "4a89c8" [headlabel="MSPAPPP"];
# 	"836925" [shape="point"];
# 	"4a89c8" -- "836925" [headlabel="MSPAPPPA"];
# 	"0a8a9d" [label="MSPAPPPAA"];
# 	"836925" -- "0a8a9d" ;
# 	"afab81" [label="MSPAPPPAP"];
# 	"836925" -- "afab81" ;
# 	"6e29a7" [shape="point"];
# 	"4a89c8" -- "6e29a7" [headlabel="MSPAPPPP"];
# 	"cdc25d" [label="MSPAPPPPA"];
# 	"6e29a7" -- "cdc25d" ;
# 	"daeece" [label="MSPAPPPPP"];
# 	"6e29a7" -- "daeece" ;
# 	"326345" [shape="point"];
# 	"e4b289" -- "326345" [headlabel="MSPP"];
# 	"e69f03" [shape="point"];
# 	"326345" -- "e69f03" [headlabel="MSPPA"];
# 	"fabfaf" [shape="point"];
# 	"e69f03" -- "fabfaf" [headlabel="MSPPAA"];
# 	"1f33a0" [shape="point"];
# 	"fabfaf" -- "1f33a0" [headlabel="MSPPAAA"];
# 	"1fb4c1" [shape="point"];
# 	"1f33a0" -- "1fb4c1" [headlabel="MSPPAAAA"];
# 	"074b7d" [label="MSPPAAAAD"];
# 	"1fb4c1" -- "074b7d" ;
# 	"4adf3f" [label="MSPPAAAAV"];
# 	"1fb4c1" -- "4adf3f" ;
# 	"c252bf" [label="MSPPAAAP"];
# 	"1f33a0" -- "c252bf" ;
# 	"820d3c" [shape="point"];
# 	"fabfaf" -- "820d3c" [headlabel="MSPPAAP"];
# 	"5e659b" [label="MSPPAAPA"];
# 	"820d3c" -- "5e659b" ;
# 	"c7a5c0" [label="MSPPAAPP"];
# 	"820d3c" -- "c7a5c0" ;
# 	"0ab481" [shape="point"];
# 	"e69f03" -- "0ab481" [headlabel="MSPPAP"];
# 	"f5de57" [shape="point"];
# 	"0ab481" -- "f5de57" [headlabel="MSPPAPA"];
# 	"5d3a72" [shape="point"];
# 	"f5de57" -- "5d3a72" [headlabel="MSPPAPAA"];
# 	"6e8f33" [label="MSPPAPAAA"];
# 	"5d3a72" -- "6e8f33" ;
# 	"5cbc46" [label="MSPPAPAAP"];
# 	"5d3a72" -- "5cbc46" ;
# 	"6537bf" [label="MSPPAPAP"];
# 	"f5de57" -- "6537bf" ;
# 	"246f39" [shape="point"];
# 	"0ab481" -- "246f39" [headlabel="MSPPAPP"];
# 	"aba7a0" [label="MSPPAPPA"];
# 	"246f39" -- "aba7a0" ;
# 	"71ef23" [label="MSPPAPPP"];
# 	"246f39" -- "71ef23" ;
# 	"57705b" [shape="point"];
# 	"326345" -- "57705b" [headlabel="MSPPP"];
# 	"20cc93" [shape="point"];
# 	"57705b" -- "20cc93" [headlabel="MSPPPA"];
# 	"c367b6" [shape="point"];
# 	"20cc93" -- "c367b6" [headlabel="MSPPPAA"];
# 	"7f3578" [label="MSPPPAAA"];
# 	"c367b6" -- "7f3578" ;
# 	"b426dd" [label="MSPPPAAP"];
# 	"c367b6" -- "b426dd" ;
# 	"ce894f" [shape="point"];
# 	"20cc93" -- "ce894f" [headlabel="MSPPPAP"];
# 	"035107" [label="MSPPPAPA"];
# 	"ce894f" -- "035107" ;
# 	"3a5a83" [label="MSPPPAPP"];
# 	"ce894f" -- "3a5a83" ;
# 	"3769bf" [shape="point"];
# 	"57705b" -- "3769bf" [headlabel="MSPPPP"];
# 	"1b7e2e" [shape="point"];
# 	"3769bf" -- "1b7e2e" [headlabel="MSPPPPA"];
# 	"222690" [label="MSPPPPAA"];
# 	"1b7e2e" -- "222690" ;
# 	"9ddec3" [label="MSPPPPAP"];
# 	"1b7e2e" -- "9ddec3" ;
# 	"80dfc8" [shape="point"];
# 	"3769bf" -- "80dfc8" [headlabel="MSPPPPP"];
# 	"f06d99" [label="MSPPPPPA"];
# 	"80dfc8" -- "f06d99" ;
# 	"219db3" [label="MSPPPPPP"];
# 	"80dfc8" -- "219db3" ;
# 	"2958bb" [shape="point"];
# 	"3ddd3a" -- "2958bb" [headlabel="P2"];
# 	"893b29" [shape="point"];
# 	"2958bb" -- "893b29" [headlabel="C"];
# 	"cd9bea" [shape="point"];
# 	"893b29" -- "cd9bea" [headlabel="CA"];
# 	"5af956" [shape="point"];
# 	"cd9bea" -- "5af956" [headlabel="CAA"];
# 	"e8a8f7" [shape="point"];
# 	"5af956" -- "e8a8f7" [headlabel="CAAA"];
# 	"120f18" [shape="point"];
# 	"e8a8f7" -- "120f18" [headlabel="CAAAA"];
# 	"2b68bc" [label="CAAAAA"];
# 	"120f18" -- "2b68bc" ;
# 	"c57961" [label="CAAAAP"];
# 	"120f18" -- "c57961" ;
# 	"b9235f" [shape="point"];
# 	"e8a8f7" -- "b9235f" [headlabel="CAAAP"];
# 	"9288e2" [label="CAAAPA"];
# 	"b9235f" -- "9288e2" ;
# 	"f110c5" [label="CAAAPP"];
# 	"b9235f" -- "f110c5" ;
# 	"6c4b2b" [shape="point"];
# 	"5af956" -- "6c4b2b" [headlabel="CAAP"];
# 	"ed33a0" [shape="point"];
# 	"6c4b2b" -- "ed33a0" [headlabel="CAAPA"];
# 	"9e20e3" [label="CAAPAA"];
# 	"ed33a0" -- "9e20e3" ;
# 	"7f3658" [label="CAAPAP"];
# 	"ed33a0" -- "7f3658" ;
# 	"8e60b3" [shape="point"];
# 	"6c4b2b" -- "8e60b3" [headlabel="CAAPP"];
# 	"27b741" [label="CAAPPD"];
# 	"8e60b3" -- "27b741" ;
# 	"153664" [label="CAAPPV"];
# 	"8e60b3" -- "153664" ;
# 	"00768d" [shape="point"];
# 	"cd9bea" -- "00768d" [headlabel="CAP"];
# 	"db1406" [shape="point"];
# 	"00768d" -- "db1406" [headlabel="CAPA"];
# 	"ce39a3" [shape="point"];
# 	"db1406" -- "ce39a3" [headlabel="CAPAA"];
# 	"d5e225" [shape="point"];
# 	"ce39a3" -- "d5e225" [headlabel="CAPAAA"];
# 	"510395" [label="CAPAAAA"];
# 	"d5e225" -- "510395" ;
# 	"89e486" [label="CAPAAAP"];
# 	"d5e225" -- "89e486" ;
# 	"1310d0" [shape="point"];
# 	"ce39a3" -- "1310d0" [headlabel="CAPAAP"];
# 	"b7aa35" [label="CAPAAPA"];
# 	"1310d0" -- "b7aa35" ;
# 	"db6e76" [label="CAPAAPP"];
# 	"1310d0" -- "db6e76" ;
# 	"8332b1" [shape="point"];
# 	"db1406" -- "8332b1" [headlabel="CAPAP"];
# 	"472934" [shape="point"];
# 	"8332b1" -- "472934" [headlabel="CAPAPA"];
# 	"d0cab2" [label="CAPAPAA"];
# 	"472934" -- "d0cab2" ;
# 	"7f5cd0" [label="CAPAPAP"];
# 	"472934" -- "7f5cd0" ;
# 	"46322f" [shape="point"];
# 	"8332b1" -- "46322f" [headlabel="CAPAPP"];
# 	"99448f" [label="CAPAPPA"];
# 	"46322f" -- "99448f" ;
# 	"e289ff" [label="CAPAPPP"];
# 	"46322f" -- "e289ff" ;
# 	"c6439d" [shape="point"];
# 	"00768d" -- "c6439d" [headlabel="CAPP"];
# 	"f2c7f3" [shape="point"];
# 	"c6439d" -- "f2c7f3" [headlabel="CAPPA"];
# 	"86794a" [shape="point"];
# 	"f2c7f3" -- "86794a" [headlabel="CAPPAA"];
# 	"fd0926" [label="CAPPAAA"];
# 	"86794a" -- "fd0926" ;
# 	"d37a3f" [label="CAPPAAP"];
# 	"86794a" -- "d37a3f" ;
# 	"9f5eab" [shape="point"];
# 	"f2c7f3" -- "9f5eab" [headlabel="CAPPAP"];
# 	"8ce289" [label="CAPPAPA"];
# 	"9f5eab" -- "8ce289" ;
# 	"8820d8" [label="CAPPAPP"];
# 	"9f5eab" -- "8820d8" ;
# 	"bcd06f" [shape="point"];
# 	"c6439d" -- "bcd06f" [headlabel="CAPPP"];
# 	"d9c53e" [shape="point"];
# 	"bcd06f" -- "d9c53e" [headlabel="CAPPPA"];
# 	"38c6bd" [label="CAPPPAA"];
# 	"d9c53e" -- "38c6bd" ;
# 	"200714" [label="CAPPPAP"];
# 	"d9c53e" -- "200714" ;
# 	"faed9a" [shape="point"];
# 	"bcd06f" -- "faed9a" [headlabel="CAPPPP"];
# 	"24db50" [label="CAPPPPD"];
# 	"faed9a" -- "24db50" ;
# 	"32a306" [label="CAPPPPV"];
# 	"faed9a" -- "32a306" ;
# 	"1a4de7" [shape="point"];
# 	"893b29" -- "1a4de7" [headlabel="CP"];
# 	"f27d06" [shape="point"];
# 	"1a4de7" -- "f27d06" [headlabel="CPA"];
# 	"6a1caa" [shape="point"];
# 	"f27d06" -- "6a1caa" [headlabel="CPAA"];
# 	"e36d92" [shape="point"];
# 	"6a1caa" -- "e36d92" [headlabel="CPAAA"];
# 	"2cbca5" [label="CPAAAA"];
# 	"e36d92" -- "2cbca5" ;
# 	"607f0d" [label="CPAAAP"];
# 	"e36d92" -- "607f0d" ;
# 	"df5ef6" [shape="point"];
# 	"6a1caa" -- "df5ef6" [headlabel="CPAAP"];
# 	"13d9eb" [label="CPAAPA"];
# 	"df5ef6" -- "13d9eb" ;
# 	"d5b319" [label="CPAAPP"];
# 	"df5ef6" -- "d5b319" ;
# 	"9b48d5" [shape="point"];
# 	"f27d06" -- "9b48d5" [headlabel="CPAP"];
# 	"ef1379" [shape="point"];
# 	"9b48d5" -- "ef1379" [headlabel="CPAPA"];
# 	"d953f5" [label="CPAPAA"];
# 	"ef1379" -- "d953f5" ;
# 	"a53f58" [label="CPAPAP"];
# 	"ef1379" -- "a53f58" ;
# 	"a243b5" [shape="point"];
# 	"9b48d5" -- "a243b5" [headlabel="CPAPP"];
# 	"357d48" [label="CPAPPD"];
# 	"a243b5" -- "357d48" ;
# 	"18256e" [label="CPAPPV"];
# 	"a243b5" -- "18256e" ;
# 	"4890c4" [shape="point"];
# 	"1a4de7" -- "4890c4" [headlabel="CPP"];
# 	"b0fbe7" [shape="point"];
# 	"4890c4" -- "b0fbe7" [headlabel="CPPA"];
# 	"f612f3" [shape="point"];
# 	"b0fbe7" -- "f612f3" [headlabel="CPPAA"];
# 	"32bc36" [shape="point"];
# 	"f612f3" -- "32bc36" [headlabel="CPPAAA"];
# 	"b6e1d6" [label="CPPAAAA"];
# 	"32bc36" -- "b6e1d6" ;
# 	"d6612a" [label="CPPAAAP"];
# 	"32bc36" -- "d6612a" ;
# 	"f36cd5" [shape="point"];
# 	"f612f3" -- "f36cd5" [headlabel="CPPAAP"];
# 	"b592af" [label="CPPAAPA"];
# 	"f36cd5" -- "b592af" ;
# 	"c43cd1" [label="CPPAAPP"];
# 	"f36cd5" -- "c43cd1" ;
# 	"7ead23" [shape="point"];
# 	"b0fbe7" -- "7ead23" [headlabel="CPPAP"];
# 	"41e373" [shape="point"];
# 	"7ead23" -- "41e373" [headlabel="CPPAPA"];
# 	"5d9fc2" [label="CPPAPAA"];
# 	"41e373" -- "5d9fc2" ;
# 	"7ccf04" [label="CPPAPAP"];
# 	"41e373" -- "7ccf04" ;
# 	"61dc56" [shape="point"];
# 	"7ead23" -- "61dc56" [headlabel="CPPAPP"];
# 	"0cd77a" [label="CPPAPPA"];
# 	"61dc56" -- "0cd77a" ;
# 	"66f1ea" [label="CPPAPPP"];
# 	"61dc56" -- "66f1ea" ;
# 	"1e3125" [shape="point"];
# 	"4890c4" -- "1e3125" [headlabel="CPPP"];
# 	"b7886c" [shape="point"];
# 	"1e3125" -- "b7886c" [headlabel="CPPPA"];
# 	"f6d827" [shape="point"];
# 	"b7886c" -- "f6d827" [headlabel="CPPPAA"];
# 	"5e13b9" [label="CPPPAAA"];
# 	"f6d827" -- "5e13b9" ;
# 	"8c4b1c" [label="CPPPAAP"];
# 	"f6d827" -- "8c4b1c" ;
# 	"b0f507" [shape="point"];
# 	"b7886c" -- "b0f507" [headlabel="CPPPAP"];
# 	"358b28" [label="CPPPAPA"];
# 	"b0f507" -- "358b28" ;
# 	"6bdfd0" [label="CPPPAPP"];
# 	"b0f507" -- "6bdfd0" ;
# 	"b50b1a" [shape="point"];
# 	"1e3125" -- "b50b1a" [headlabel="CPPPP"];
# 	"403646" [shape="point"];
# 	"b50b1a" -- "403646" [headlabel="CPPPPA"];
# 	"41fc5a" [label="CPPPPAA"];
# 	"403646" -- "41fc5a" ;
# 	"0a5363" [label="CPPPPAP"];
# 	"403646" -- "0a5363" ;
# 	"ac8903" [shape="point"];
# 	"b50b1a" -- "ac8903" [headlabel="CPPPPP"];
# 	"79c07e" [label="CPPPPPD"];
# 	"ac8903" -- "79c07e" ;
# 	"6c356f" [label="CPPPPPV"];
# 	"ac8903" -- "6c356f" ;
# 	"882783" [shape="point"];
# 	"2958bb" -- "882783" [headlabel="P3"];
# 	"01235f" [shape="point"];
# 	"882783" -- "01235f" [headlabel="D"];
# 	"b2f909" [shape="point"];
# 	"01235f" -- "b2f909" [headlabel="DA"];
# 	"5eb91c" [shape="point"];
# 	"b2f909" -- "5eb91c" [headlabel="DAA"];
# 	"582b2a" [shape="point"];
# 	"5eb91c" -- "582b2a" [headlabel="DAAA"];
# 	"ff1d4e" [label="DAAAA"];
# 	"582b2a" -- "ff1d4e" ;
# 	"e36c5e" [label="DAAAP"];
# 	"582b2a" -- "e36c5e" ;
# 	"92849b" [shape="point"];
# 	"5eb91c" -- "92849b" [headlabel="DAAP"];
# 	"02380c" [label="DAAPA"];
# 	"92849b" -- "02380c" ;
# 	"27166b" [label="DAAPP"];
# 	"92849b" -- "27166b" ;
# 	"0de2a3" [shape="point"];
# 	"b2f909" -- "0de2a3" [headlabel="DAP"];
# 	"1a0e8d" [shape="point"];
# 	"0de2a3" -- "1a0e8d" [headlabel="DAPA"];
# 	"ae3cf7" [label="DAPAA"];
# 	"1a0e8d" -- "ae3cf7" ;
# 	"f0cced" [label="DAPAP"];
# 	"1a0e8d" -- "f0cced" ;
# 	"570515" [shape="point"];
# 	"0de2a3" -- "570515" [headlabel="DAPP"];
# 	"493036" [shape="point"];
# 	"570515" -- "493036" [headlabel="DAPPA"];
# 	"94ed03" [label="DAPPAA"];
# 	"493036" -- "94ed03" ;
# 	"2e15aa" [label="DAPPAP"];
# 	"493036" -- "2e15aa" ;
# 	"9a6deb" [shape="point"];
# 	"570515" -- "9a6deb" [headlabel="DAPPP"];
# 	"32077f" [label="DAPPPA"];
# 	"9a6deb" -- "32077f" ;
# 	"2e7cb9" [label="DAPPPP"];
# 	"9a6deb" -- "2e7cb9" ;
# 	"3f8776" [shape="point"];
# 	"01235f" -- "3f8776" [headlabel="DP"];
# 	"5882ea" [shape="point"];
# 	"3f8776" -- "5882ea" [headlabel="DPA"];
# 	"499491" [shape="point"];
# 	"5882ea" -- "499491" [headlabel="DPAA"];
# 	"57ab44" [label="DPAAA"];
# 	"499491" -- "57ab44" ;
# 	"4863d5" [label="DPAAP"];
# 	"499491" -- "4863d5" ;
# 	"5d83ee" [shape="point"];
# 	"5882ea" -- "5d83ee" [headlabel="DPAP"];
# 	"7ffc58" [label="DPAPA"];
# 	"5d83ee" -- "7ffc58" ;
# 	"989e7e" [label="DPAPP"];
# 	"5d83ee" -- "989e7e" ;
# 	"195192" [shape="point"];
# 	"3f8776" -- "195192" [headlabel="DPP"];
# 	"678190" [shape="point"];
# 	"195192" -- "678190" [headlabel="DPPA"];
# 	"c930a3" [label="DPPAA"];
# 	"678190" -- "c930a3" ;
# 	"75d523" [label="DPPAP"];
# 	"678190" -- "75d523" ;
# 	"19503c" [shape="point"];
# 	"195192" -- "19503c" [headlabel="DPPP"];
# 	"777a91" [shape="point"];
# 	"19503c" -- "777a91" [headlabel="DPPPA"];
# 	"7e8206" [label="DPPPAA"];
# 	"777a91" -- "7e8206" ;
# 	"d45e7a" [label="DPPPAP"];
# 	"777a91" -- "d45e7a" ;
# 	"e6b586" [shape="point"];
# 	"19503c" -- "e6b586" [headlabel="DPPPP"];
# 	"57a661" [label="DPPPPA"];
# 	"e6b586" -- "57a661" ;
# 	"2a029d" [label="DPPPPP"];
# 	"e6b586" -- "2a029d" ;
# 	"57c93f" [shape="point"];
# 	"882783" -- "57c93f" [headlabel="P4"];
# 	"d62a45" [label="P4A"];
# 	"57c93f" -- "d62a45" ;
# 	"35f440" [label="P4P"];
# 	"57c93f" -- "35f440" ;
# }
